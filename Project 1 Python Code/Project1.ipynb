# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Dependencies and Setup

# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
from pathlib import Path
from itertools import product
import scipy.stats as stats
from scipy.stats import pearsonr
from scipy import stats
from scipy.stats import normaltest

# %%
#Create a file path
data_set = Path("../Resources/world_wide_self_harm_and_substance_deaths.csv")

#Read in the data
df = pd.read_csv(data_set)
df.head()
# Out:
#    Year                  Cause Age_Range ISO_Code     Sex  Deaths  \
# 0  2017  Intentional self-harm         0      GBR  Female       0
# 1  2017  Intentional self-harm         0      GBR    Male       0
# 2  2017  Intentional self-harm         1      GBR  Female       0
# 3  2017  Intentional self-harm         1      GBR    Male       0
# 4  2017  Intentional self-harm     10-14      GBR  Female      16
#
#    Age_and_Sex_Population         Country
# 0                743552.0  United Kingdom
# 1                782850.0  United Kingdom
# 2                768444.0  United Kingdom
# 3                810126.0  United Kingdom
# 4               3640314.0  United Kingdom

# %%
df1=df[~(df[df.columns[2:]]==0).any(axis = 1)]
df1
# Out:
#        Year                                              Cause Age_Range  \
# 4      2017                              Intentional self-harm     10-14
# 5      2017                              Intentional self-harm     10-14
# 6      2017                              Intentional self-harm     15-19
# 7      2017                              Intentional self-harm     15-19
# 10     2017                              Intentional self-harm     20-24
# ...     ...                                                ...       ...
# 48621  2017  Mental and behavioural disorders due to psycho...     60-64
# 48622  2017  Mental and behavioural disorders due to psycho...     65-69
# 48623  2017  Mental and behavioural disorders due to psycho...     70-74
# 48625  2017  Mental and behavioural disorders due to psycho...     80-84
# 48629  2017  Mental and behavioural disorders due to psycho...       All
#
#       ISO_Code     Sex  Deaths  Age_and_Sex_Population               Country
# 4          GBR  Female      16               3640314.0        United Kingdom
# 5          GBR    Male      16               3826458.0        United Kingdom
# 6          GBR  Female     104               3605202.0        United Kingdom
# 7          GBR    Male     208               3803268.0        United Kingdom
# 10         GBR  Female     136               4097544.0        United Kingdom
# ...        ...     ...     ...                     ...                   ...
# 48621      VIR     All       1                     NaN  Virgin Islands (USA)
# 48622      VIR     All       1                     NaN  Virgin Islands (USA)
# 48623      VIR     All       1                     NaN  Virgin Islands (USA)
# 48625      VIR     All       1                     NaN  Virgin Islands (USA)
# 48629      VIR     All       9                101860.0  Virgin Islands (USA)
#
# [25354 rows x 8 columns]

# %%
df2=df1[~(df1[df1.columns[2:]]=="Unknown").any(axis = 1)]
df2
# Out:
#        Year                                              Cause Age_Range  \
# 4      2017                              Intentional self-harm     10-14
# 5      2017                              Intentional self-harm     10-14
# 6      2017                              Intentional self-harm     15-19
# 7      2017                              Intentional self-harm     15-19
# 10     2017                              Intentional self-harm     20-24
# ...     ...                                                ...       ...
# 48621  2017  Mental and behavioural disorders due to psycho...     60-64
# 48622  2017  Mental and behavioural disorders due to psycho...     65-69
# 48623  2017  Mental and behavioural disorders due to psycho...     70-74
# 48625  2017  Mental and behavioural disorders due to psycho...     80-84
# 48629  2017  Mental and behavioural disorders due to psycho...       All
#
#       ISO_Code     Sex  Deaths  Age_and_Sex_Population               Country
# 4          GBR  Female      16               3640314.0        United Kingdom
# 5          GBR    Male      16               3826458.0        United Kingdom
# 6          GBR  Female     104               3605202.0        United Kingdom
# 7          GBR    Male     208               3803268.0        United Kingdom
# 10         GBR  Female     136               4097544.0        United Kingdom
# ...        ...     ...     ...                     ...                   ...
# 48621      VIR     All       1                     NaN  Virgin Islands (USA)
# 48622      VIR     All       1                     NaN  Virgin Islands (USA)
# 48623      VIR     All       1                     NaN  Virgin Islands (USA)
# 48625      VIR     All       1                     NaN  Virgin Islands (USA)
# 48629      VIR     All       9                101860.0  Virgin Islands (USA)
#
# [25182 rows x 8 columns]

# %%
df3=df2[~(df2[df2.columns[2:]]=="All").any(axis = 1)]
df3
# Out:
#        Year                                              Cause Age_Range  \
# 4      2017                              Intentional self-harm     10-14
# 5      2017                              Intentional self-harm     10-14
# 6      2017                              Intentional self-harm     15-19
# 7      2017                              Intentional self-harm     15-19
# 10     2017                              Intentional self-harm     20-24
# ...     ...                                                ...       ...
# 31935  2021  Mental and behavioural disorders due to psycho...     80-84
# 31936  2021  Mental and behavioural disorders due to psycho...     85-89
# 31937  2021  Mental and behavioural disorders due to psycho...     90-94
# 31938  2021  Mental and behavioural disorders due to psycho...       95+
# 31949  2017                              Intentional self-harm     30-34
#
#       ISO_Code     Sex  Deaths  Age_and_Sex_Population          Country
# 4          GBR  Female      16            3.640314e+06   United Kingdom
# 5          GBR    Male      16            3.826458e+06   United Kingdom
# 6          GBR  Female     104            3.605202e+06   United Kingdom
# 7          GBR    Male     208            3.803268e+06   United Kingdom
# 10         GBR  Female     136            4.097544e+06   United Kingdom
# ...        ...     ...     ...                     ...              ...
# 31935      AUS    Male      13            2.499620e+05        Australia
# 31936      AUS    Male       7            1.357450e+05        Australia
# 31937      AUS    Male       4            5.877900e+04        Australia
# 31938      AUS    Male       2            1.429300e+04        Australia
# 31949      SLB    Male       1            2.441201e+04  Solomon Islands
#
# [14764 rows x 8 columns]

# %%
df4=df3[~(df3[df3.columns[2:3]]=="5-9").any(axis = 1)]
df4
# Out:
#        Year                                              Cause Age_Range  \
# 4      2017                              Intentional self-harm     10-14
# 5      2017                              Intentional self-harm     10-14
# 6      2017                              Intentional self-harm     15-19
# 7      2017                              Intentional self-harm     15-19
# 10     2017                              Intentional self-harm     20-24
# ...     ...                                                ...       ...
# 31935  2021  Mental and behavioural disorders due to psycho...     80-84
# 31936  2021  Mental and behavioural disorders due to psycho...     85-89
# 31937  2021  Mental and behavioural disorders due to psycho...     90-94
# 31938  2021  Mental and behavioural disorders due to psycho...       95+
# 31949  2017                              Intentional self-harm     30-34
#
#       ISO_Code     Sex  Deaths  Age_and_Sex_Population          Country
# 4          GBR  Female      16            3.640314e+06   United Kingdom
# 5          GBR    Male      16            3.826458e+06   United Kingdom
# 6          GBR  Female     104            3.605202e+06   United Kingdom
# 7          GBR    Male     208            3.803268e+06   United Kingdom
# 10         GBR  Female     136            4.097544e+06   United Kingdom
# ...        ...     ...     ...                     ...              ...
# 31935      AUS    Male      13            2.499620e+05        Australia
# 31936      AUS    Male       7            1.357450e+05        Australia
# 31937      AUS    Male       4            5.877900e+04        Australia
# 31938      AUS    Male       2            1.429300e+04        Australia
# 31949      SLB    Male       1            2.441201e+04  Solomon Islands
#
# [14655 rows x 8 columns]

# %%
# Get all the data for the United States of America 
usa_df = df4.loc[df["Country"] == "United States of America",:]           
                 
usa_df
# Out:
#        Year                                              Cause Age_Range  \
# 10451  2017                              Intentional self-harm     10-14
# 10452  2017                              Intentional self-harm     15-19
# 10454  2017                              Intentional self-harm     20-24
# 10455  2017                              Intentional self-harm     25-29
# 10457  2017                              Intentional self-harm     30-34
# ...     ...                                                ...       ...
# 10858  2020  Mental and behavioural disorders due to psycho...     75-79
# 10859  2020  Mental and behavioural disorders due to psycho...     80-84
# 10860  2020  Mental and behavioural disorders due to psycho...     85-89
# 10861  2020  Mental and behavioural disorders due to psycho...     90-94
# 10862  2020  Mental and behavioural disorders due to psycho...       95+
#
#       ISO_Code     Sex  Deaths  Age_and_Sex_Population  \
# 10451      USA  Female     169                     NaN
# 10452      USA  Female     553                     NaN
# 10454      USA  Female     672                     NaN
# 10455      USA  Female     766                     NaN
# 10457      USA  Female     832                     NaN
# ...        ...     ...     ...                     ...
# 10858      USA    Male     461                     NaN
# 10859      USA    Male     199                     NaN
# 10860      USA    Male     116                     NaN
# 10861      USA    Male      43                     NaN
# 10862      USA    Male       7                     NaN
#
#                         Country
# 10451  United States of America
# 10452  United States of America
# 10454  United States of America
# 10455  United States of America
# 10457  United States of America
# ...                         ...
# 10858  United States of America
# 10859  United States of America
# 10860  United States of America
# 10861  United States of America
# 10862  United States of America
#
# [282 rows x 8 columns]

# %%
# Get all the data for the Intentional self-harm 
selfharm_df = usa_df.loc[usa_df["Cause"] == "Intentional self-harm", :] 
selfharm_df
# Out:
#        Year                  Cause Age_Range ISO_Code     Sex  Deaths  \
# 10451  2017  Intentional self-harm     10-14      USA  Female     169
# 10452  2017  Intentional self-harm     15-19      USA  Female     553
# 10454  2017  Intentional self-harm     20-24      USA  Female     672
# 10455  2017  Intentional self-harm     25-29      USA  Female     766
# 10457  2017  Intentional self-harm     30-34      USA  Female     832
# ...     ...                    ...       ...      ...     ...     ...
# 10806  2020  Intentional self-harm     75-79      USA    Male    1492
# 10807  2020  Intentional self-harm     80-84      USA    Male    1153
# 10808  2020  Intentional self-harm     85-89      USA    Male     778
# 10809  2020  Intentional self-harm     90-94      USA    Male     389
# 10810  2020  Intentional self-harm       95+      USA    Male      88
#
#        Age_and_Sex_Population                   Country
# 10451                     NaN  United States of America
# 10452                     NaN  United States of America
# 10454                     NaN  United States of America
# 10455                     NaN  United States of America
# 10457                     NaN  United States of America
# ...                       ...                       ...
# 10806                     NaN  United States of America
# 10807                     NaN  United States of America
# 10808                     NaN  United States of America
# 10809                     NaN  United States of America
# 10810                     NaN  United States of America
#
# [144 rows x 8 columns]

# %%
selfharm_df.count()
# Out:
# Year                      144
# Cause                     144
# Age_Range                 144
# ISO_Code                  144
# Sex                       144
# Deaths                    144
# Age_and_Sex_Population      0
# Country                   144
# dtype: int64

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of USA for each year.

# Use groupby and summary statistical methods to calculate the following properties of each year: 
# mean, median, variance, standard deviation, and SEM of the country. 
mean = selfharm_df['Deaths'].groupby(selfharm_df['Year']).mean()
median = selfharm_df['Deaths'].groupby(selfharm_df['Year']).var()
var = selfharm_df['Deaths'].groupby(selfharm_df['Year']).var()
std = selfharm_df['Deaths'].groupby(selfharm_df['Year']).std()
sem = selfharm_df['Deaths'].groupby(selfharm_df['Year']).sem()

# Assemble the resulting series into a single summary DataFrame.
summary_stat = pd.DataFrame({"Self- Harm Deaths Mean":mean, 
                            "Self-Harm Deaths Median":median, 
                           "Self-Harm Variance":var, 
                           "Self-Harm Std. Dev.":std, 
                           "Self-Harm Std. Err.":sem})

summary_stat
# Out:
#       Self- Harm Deaths Mean  Self-Harm Deaths Median  Self-Harm Variance  \
# Year
# 2017             1308.250000             1.268233e+06        1.268233e+06
# 2018             1341.750000             1.328915e+06        1.328915e+06
# 2019             1318.388889             1.293741e+06        1.293741e+06
# 2020             1275.500000             1.230823e+06        1.230823e+06
#
#       Self-Harm Std. Dev.  Self-Harm Std. Err.
# Year
# 2017          1126.158359           187.693060
# 2018          1152.785605           192.130934
# 2019          1137.427505           189.571251
# 2020          1109.424574           184.904096

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_agg =  selfharm_df.groupby(['Year'])[['Deaths']].agg(['mean', 'median'])
summary_agg
# Out:
#            Deaths
#              mean median
# Year
# 2017  1308.250000  876.5
# 2018  1341.750000  880.0
# 2019  1318.388889  863.5
# 2020  1275.500000  805.0

# %%
intentionaldeaths = selfharm_df['Deaths']
plt.hist(intentionaldeaths)
plt.xlabel('Intentional Self-Harm Deaths in the United States of America (2017-2020)')
plt.ylabel('Counts')
plt.show()
print(st.normaltest(intentionaldeaths.sample(144)))
plt.savefig("output_data/Fig3.png")
# Out:
# NormaltestResult(statistic=34.51392567404926, pvalue=3.20181522544649e-08)

# %%
#**It fails the normality test because the Pvalue=pvalue= 3.201815225446364e-08 is  very small. 
#iven the complete dataset we can conclude that the data is not normally distributed.

# %%
deaths = selfharm_df["Deaths"]
fig1, ax1 = plt.subplots()
ax1.set_title('The United States of America (2017-2020)')
ax1.set_ylabel('Intentional Self-Harm Deaths')
ax1.boxplot(deaths)
plt.show()

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
quartiles = deaths.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of deaths is: {lowerq}")
print(f"The upper quartile of deaths is: {upperq}")
print(f"The interquartile range of deaths is: {iqr}")
print(f"The the median of deaths is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of deaths is: 390.75
# The upper quartile of deaths is: 2318.25
# The interquartile range of deaths is: 1927.5
# The the median of deaths is: 863.5
# Values below -2500.5 could be outliers.
# Values above 5209.5 could be outliers.

# %%
# Generate a scatter plot of intentional self-harm deaths vs age for year 2020
# Extruct columns of interest from original data frame:
year2020_df = selfharm_df.loc[selfharm_df["Year"] == 2020, :] 
year2020_df
# Out:
#        Year                  Cause Age_Range ISO_Code     Sex  Deaths  \
# 10763  2020  Intentional self-harm     10-14      USA  Female     204
# 10764  2020  Intentional self-harm     15-19      USA  Female     526
# 10766  2020  Intentional self-harm     20-24      USA  Female     676
# 10767  2020  Intentional self-harm     25-29      USA  Female     786
# 10769  2020  Intentional self-harm     30-34      USA  Female     785
# 10770  2020  Intentional self-harm     35-39      USA  Female     824
# 10772  2020  Intentional self-harm     40-44      USA  Female     766
# 10773  2020  Intentional self-harm     45-49      USA  Female     843
# 10775  2020  Intentional self-harm     50-54      USA  Female     891
# 10776  2020  Intentional self-harm     55-59      USA  Female     896
# 10777  2020  Intentional self-harm     60-64      USA  Female     719
# 10778  2020  Intentional self-harm     65-69      USA  Female     558
# 10779  2020  Intentional self-harm     70-74      USA  Female     413
# 10780  2020  Intentional self-harm     75-79      USA  Female     244
# 10781  2020  Intentional self-harm     80-84      USA  Female     143
# 10782  2020  Intentional self-harm     85-89      USA  Female      84
# 10783  2020  Intentional self-harm     90-94      USA  Female      43
# 10784  2020  Intentional self-harm       95+      USA  Female       7
# 10789  2020  Intentional self-harm     10-14      USA    Male     376
# 10790  2020  Intentional self-harm     15-19      USA    Male    1688
# 10792  2020  Intentional self-harm     20-24      USA    Male    3168
# 10793  2020  Intentional self-harm     25-29      USA    Male    3412
# 10795  2020  Intentional self-harm     30-34      USA    Male    3463
# 10796  2020  Intentional self-harm     35-39      USA    Male    3008
# 10798  2020  Intentional self-harm     40-44      USA    Male    2713
# 10799  2020  Intentional self-harm     45-49      USA    Male    2733
# 10801  2020  Intentional self-harm     50-54      USA    Male    2777
# 10802  2020  Intentional self-harm     55-59      USA    Male    2924
# 10803  2020  Intentional self-harm     60-64      USA    Male    2610
# 10804  2020  Intentional self-harm     65-69      USA    Male    2040
# 10805  2020  Intentional self-harm     70-74      USA    Male    1698
# 10806  2020  Intentional self-harm     75-79      USA    Male    1492
# 10807  2020  Intentional self-harm     80-84      USA    Male    1153
# 10808  2020  Intentional self-harm     85-89      USA    Male     778
# 10809  2020  Intentional self-harm     90-94      USA    Male     389
# 10810  2020  Intentional self-harm       95+      USA    Male      88
#
#        Age_and_Sex_Population                   Country
# 10763                     NaN  United States of America
# 10764                     NaN  United States of America
# 10766                     NaN  United States of America
# 10767                     NaN  United States of America
# 10769                     NaN  United States of America
# 10770                     NaN  United States of America
# 10772                     NaN  United States of America
# 10773                     NaN  United States of America
# 10775                     NaN  United States of America
# 10776                     NaN  United States of America
# 10777                     NaN  United States of America
# 10778                     NaN  United States of America
# 10779                     NaN  United States of America
# 10780                     NaN  United States of America
# 10781                     NaN  United States of America
# 10782                     NaN  United States of America
# 10783                     NaN  United States of America
# 10784                     NaN  United States of America
# 10789                     NaN  United States of America
# 10790                     NaN  United States of America
# 10792                     NaN  United States of America
# 10793                     NaN  United States of America
# 10795                     NaN  United States of America
# 10796                     NaN  United States of America
# 10798                     NaN  United States of America
# 10799                     NaN  United States of America
# 10801                     NaN  United States of America
# 10802                     NaN  United States of America
# 10803                     NaN  United States of America
# 10804                     NaN  United States of America
# 10805                     NaN  United States of America
# 10806                     NaN  United States of America
# 10807                     NaN  United States of America
# 10808                     NaN  United States of America
# 10809                     NaN  United States of America
# 10810                     NaN  United States of America

# %%
# Calculate the final intentional self-harm deaths by year
# 2017, 2018, 2019, and 2020
year2017_df = selfharm_df.loc[selfharm_df["Year"] == 2017,:]
year2018_df = selfharm_df.loc[selfharm_df["Year"] == 2018, :]
year2019_df = selfharm_df.loc[selfharm_df["Year"] == 2019, :]
year2020_df = selfharm_df.loc[selfharm_df["Year"] == 2020, :]

year2017_df
# Out:
#        Year                  Cause Age_Range ISO_Code     Sex  Deaths  \
# 10451  2017  Intentional self-harm     10-14      USA  Female     169
# 10452  2017  Intentional self-harm     15-19      USA  Female     553
# 10454  2017  Intentional self-harm     20-24      USA  Female     672
# 10455  2017  Intentional self-harm     25-29      USA  Female     766
# 10457  2017  Intentional self-harm     30-34      USA  Female     832
# 10458  2017  Intentional self-harm     35-39      USA  Female     833
# 10460  2017  Intentional self-harm     40-44      USA  Female     904
# 10461  2017  Intentional self-harm     45-49      USA  Female    1108
# 10463  2017  Intentional self-harm     50-54      USA  Female    1120
# 10464  2017  Intentional self-harm     55-59      USA  Female    1091
# 10465  2017  Intentional self-harm     60-64      USA  Female     849
# 10466  2017  Intentional self-harm     65-69      USA  Female     590
# 10467  2017  Intentional self-harm     70-74      USA  Female     391
# 10468  2017  Intentional self-harm     75-79      USA  Female     233
# 10469  2017  Intentional self-harm     80-84      USA  Female     122
# 10470  2017  Intentional self-harm     85-89      USA  Female      95
# 10471  2017  Intentional self-harm     90-94      USA  Female      33
# 10472  2017  Intentional self-harm       95+      USA  Female      17
# 10477  2017  Intentional self-harm     10-14      USA    Male     348
# 10478  2017  Intentional self-harm     15-19      USA    Male    1935
# 10480  2017  Intentional self-harm     20-24      USA    Male    3081
# 10481  2017  Intentional self-harm     25-29      USA    Male    3296
# 10483  2017  Intentional self-harm     30-34      USA    Male    3042
# 10484  2017  Intentional self-harm     35-39      USA    Male    2884
# 10486  2017  Intentional self-harm     40-44      USA    Male    2702
# 10487  2017  Intentional self-harm     45-49      USA    Male    3116
# 10489  2017  Intentional self-harm     50-54      USA    Male    3205
# 10490  2017  Intentional self-harm     55-59      USA    Male    3324
# 10491  2017  Intentional self-harm     60-64      USA    Male    2707
# 10492  2017  Intentional self-harm     65-69      USA    Male    1964
# 10493  2017  Intentional self-harm     70-74      USA    Male    1669
# 10494  2017  Intentional self-harm     75-79      USA    Male    1302
# 10495  2017  Intentional self-harm     80-84      USA    Male     990
# 10496  2017  Intentional self-harm     85-89      USA    Male     753
# 10497  2017  Intentional self-harm     90-94      USA    Male     334
# 10498  2017  Intentional self-harm       95+      USA    Male      67
#
#        Age_and_Sex_Population                   Country
# 10451                     NaN  United States of America
# 10452                     NaN  United States of America
# 10454                     NaN  United States of America
# 10455                     NaN  United States of America
# 10457                     NaN  United States of America
# 10458                     NaN  United States of America
# 10460                     NaN  United States of America
# 10461                     NaN  United States of America
# 10463                     NaN  United States of America
# 10464                     NaN  United States of America
# 10465                     NaN  United States of America
# 10466                     NaN  United States of America
# 10467                     NaN  United States of America
# 10468                     NaN  United States of America
# 10469                     NaN  United States of America
# 10470                     NaN  United States of America
# 10471                     NaN  United States of America
# 10472                     NaN  United States of America
# 10477                     NaN  United States of America
# 10478                     NaN  United States of America
# 10480                     NaN  United States of America
# 10481                     NaN  United States of America
# 10483                     NaN  United States of America
# 10484                     NaN  United States of America
# 10486                     NaN  United States of America
# 10487                     NaN  United States of America
# 10489                     NaN  United States of America
# 10490                     NaN  United States of America
# 10491                     NaN  United States of America
# 10492                     NaN  United States of America
# 10493                     NaN  United States of America
# 10494                     NaN  United States of America
# 10495                     NaN  United States of America
# 10496                     NaN  United States of America
# 10497                     NaN  United States of America
# 10498                     NaN  United States of America

# %%
# Start by getting the last (greatest) deaths for year 2017
year2017_last = year2017_df.groupby('Year').max()['Deaths']
year2017_vol = pd.DataFrame(year2017_last)
# Merge this group df with the original DataFrame to get Age range
year2017_merge = pd.merge(year2017_vol, selfharm_df, on=("Year","Deaths"),how="left")

year2017_merge
# Out:
#    Year  Deaths                  Cause Age_Range ISO_Code   Sex  \
# 0  2017    3324  Intentional self-harm     55-59      USA  Male
#
#    Age_and_Sex_Population                   Country
# 0                     NaN  United States of America

# %%
# Start by getting the last (greatest) deaths for year 2018
year2018_last = year2018_df.groupby('Year').max()['Deaths']
year2018_vol = pd.DataFrame(year2018_last)
# Merge this group df with the original DataFrame to get Age range
year2018_merge = pd.merge(year2018_vol, selfharm_df, on=("Year","Deaths"),how="left")

year2018_merge
# Out:
#    Year  Deaths                  Cause Age_Range ISO_Code   Sex  \
# 0  2018    3569  Intentional self-harm     55-59      USA  Male
#
#    Age_and_Sex_Population                   Country
# 0                     NaN  United States of America

# %%
# Start by getting the last (greatest) deaths for year 2019
year2019_last = year2019_df.groupby('Year').max()['Deaths']
year2019_vol = pd.DataFrame(year2019_last)
# Merge this group df with the original DataFrame to get the age range
year2019_merge = pd.merge(year2019_vol, selfharm_df, on=("Year","Deaths"),how="left")

year2019_merge
# Out:
#    Year  Deaths                  Cause Age_Range ISO_Code   Sex  \
# 0  2019    3483  Intentional self-harm     55-59      USA  Male
#
#    Age_and_Sex_Population                   Country
# 0                     NaN  United States of America

# %%
# Start by getting the last (greatest) deaths for year 2020
year2020_last = year2020_df.groupby('Year').max()['Deaths']
year2020_vol = pd.DataFrame(year2020_last)
# Merge this group df with the original DataFrame to get age range
year2020_merge = pd.merge(year2020_vol, selfharm_df, on=("Year","Deaths"),how="left")

year2020_merge
# Out:
#    Year  Deaths                  Cause Age_Range ISO_Code   Sex  \
# 0  2020    3463  Intentional self-harm     30-34      USA  Male
#
#    Age_and_Sex_Population                   Country
# 0                     NaN  United States of America

# %%
# Create empty list to fill with year data (for plotting)
# add subset  
year_list = [2017, 2018, 2019, 2020]
years = selfharm_df[selfharm_df["Year"].isin(year_list)]
# Locate the rows which contain deaths on each year and get the numbers of deaths 
# Start by getting the last (greatest) deaths for each year
last_death = years.groupby(["Year", "Age_Range"]).agg(number_deaths=("Deaths", lambda x: x.iloc[-1]))

#Reshape dataframe
last_death = last_death.stack(level=0).unstack(level=0)
# Put years into a list for for loop (and later for plot labels)
yearnum = 0
for year in year_list:
    quartiles = last_death[year].quantile([.25,.5,.75]).round(2)
    lowerq = quartiles[0.25].round(2)
    upperq = quartiles[0.75].round(2)
# Calculate the IQR and quantitatively determine if there are any potential outliers.
    iqr = round(upperq-lowerq,2)
# Determine outliers using upper and lower bounds
    lower_bound = round(lowerq - (1.5*iqr),)
    upper_bound = round(upperq + (1.5*iqr),2)

    if yearnum == 0:
           print(f" ")
    print(f"{year}'s potential outliers: {lower_bound}   {upper_bound}")
       
     
    yearnum +=1
# Out:
#
# 2017's potential outliers: -1937   6076.12
# 2018's potential outliers: -1782   5974.5
# 2019's potential outliers: -1672   5886.25
# 2020's potential outliers: -1236   5361.5

# %%
#Reshape dataframe
boxplot_list = []
for years in year_list:
    boxplot_list.append(list(last_death[years]))
    
fig, ax=plt.subplots(1, figsize=(7, 5))
bp=ax.boxplot(boxplot_list)
ax.set_xticks([1,2,3,4], year_list)
ax.set_ylabel("Self Harm Deaths")
for flier in bp['fliers']:
    flier.set(marker='o', markersize=10, markerfacecolor='crimson', alpha=1)

plt.show()

# %%
Female = year2020_df.loc[year2020_df["Sex"] == 'Female', :] 
Male = year2020_df.loc[year2020_df["Sex"]=='Male', :]

# %%
# Build scatter plot for deaths vs. age for 2020

plt.scatter(Male['Age_Range'],Male['Deaths'], marker='o', edgecolor='black', label="Male")

plt.scatter(Female['Age_Range'],Female['Deaths'], marker='o', edgecolor='red', label='Female')

#plt.legend(handles=[male, female], loc="best")
##plt.scatter(year2020_df['Age_Range'],year2020_df['Deaths'], marker='o', edgecolor='black')

# Incorporate the other graph properties

plt.xticks(rotation=75)
plt.xlabel('Age')
plt.ylabel('Deaths')
plt.title('2020 Intentional Self-Harm Deaths In USA')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig1.png")


plt.show()

# %%
# Define a function to create Linear Regression plots

def linear_reg(x_axis, y_axis,eq_loc):  
    correlation = st.pearsonr(x_axis,y_axis)
    p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
    p_fit = p_slope * x_axis + p_int
    eq= f"y ={p_slope: .2f}x +{ p_int: .2f}"
       
    #Plot the line
    plt.scatter(x_axis, y_axis ,marker="o")
    plt.plot(x_axis,p_fit,"--", color='red')
    plt.annotate(eq, eq_loc, fontsize=12, color='red')
    print(f"The r-value between {x_axis.name} and {y_axis.name} is {round(correlation[0],2)}")

# %%
# Display 2020 data
year2020_df.head()
# Out:
#        Year                  Cause Age_Range ISO_Code     Sex  Deaths  \
# 10763  2020  Intentional self-harm     10-14      USA  Female     204
# 10764  2020  Intentional self-harm     15-19      USA  Female     526
# 10766  2020  Intentional self-harm     20-24      USA  Female     676
# 10767  2020  Intentional self-harm     25-29      USA  Female     786
# 10769  2020  Intentional self-harm     30-34      USA  Female     785
#
#        Age_and_Sex_Population                   Country
# 10763                     NaN  United States of America
# 10764                     NaN  United States of America
# 10766                     NaN  United States of America
# 10767                     NaN  United States of America
# 10769                     NaN  United States of America

# %%
# get valuest from Age range
 
year2020_df["newagerange"]=year2020_df['Age_Range'].str[:2]   
  
year2020_df
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_19244\784015250.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year2020_df["newagerange"]=year2020_df['Age_Range'].str[:2]
#        Year                  Cause Age_Range ISO_Code     Sex  Deaths  \
# 10763  2020  Intentional self-harm     10-14      USA  Female     204
# 10764  2020  Intentional self-harm     15-19      USA  Female     526
# 10766  2020  Intentional self-harm     20-24      USA  Female     676
# 10767  2020  Intentional self-harm     25-29      USA  Female     786
# 10769  2020  Intentional self-harm     30-34      USA  Female     785
# 10770  2020  Intentional self-harm     35-39      USA  Female     824
# 10772  2020  Intentional self-harm     40-44      USA  Female     766
# 10773  2020  Intentional self-harm     45-49      USA  Female     843
# 10775  2020  Intentional self-harm     50-54      USA  Female     891
# 10776  2020  Intentional self-harm     55-59      USA  Female     896
# 10777  2020  Intentional self-harm     60-64      USA  Female     719
# 10778  2020  Intentional self-harm     65-69      USA  Female     558
# 10779  2020  Intentional self-harm     70-74      USA  Female     413
# 10780  2020  Intentional self-harm     75-79      USA  Female     244
# 10781  2020  Intentional self-harm     80-84      USA  Female     143
# 10782  2020  Intentional self-harm     85-89      USA  Female      84
# 10783  2020  Intentional self-harm     90-94      USA  Female      43
# 10784  2020  Intentional self-harm       95+      USA  Female       7
# 10789  2020  Intentional self-harm     10-14      USA    Male     376
# 10790  2020  Intentional self-harm     15-19      USA    Male    1688
# 10792  2020  Intentional self-harm     20-24      USA    Male    3168
# 10793  2020  Intentional self-harm     25-29      USA    Male    3412
# 10795  2020  Intentional self-harm     30-34      USA    Male    3463
# 10796  2020  Intentional self-harm     35-39      USA    Male    3008
# 10798  2020  Intentional self-harm     40-44      USA    Male    2713
# 10799  2020  Intentional self-harm     45-49      USA    Male    2733
# 10801  2020  Intentional self-harm     50-54      USA    Male    2777
# 10802  2020  Intentional self-harm     55-59      USA    Male    2924
# 10803  2020  Intentional self-harm     60-64      USA    Male    2610
# 10804  2020  Intentional self-harm     65-69      USA    Male    2040
# 10805  2020  Intentional self-harm     70-74      USA    Male    1698
# 10806  2020  Intentional self-harm     75-79      USA    Male    1492
# 10807  2020  Intentional self-harm     80-84      USA    Male    1153
# 10808  2020  Intentional self-harm     85-89      USA    Male     778
# 10809  2020  Intentional self-harm     90-94      USA    Male     389
# 10810  2020  Intentional self-harm       95+      USA    Male      88
#
#        Age_and_Sex_Population                   Country newagerange
# 10763                     NaN  United States of America          10
# 10764                     NaN  United States of America          15
# 10766                     NaN  United States of America          20
# 10767                     NaN  United States of America          25
# 10769                     NaN  United States of America          30
# 10770                     NaN  United States of America          35
# 10772                     NaN  United States of America          40
# 10773                     NaN  United States of America          45
# 10775                     NaN  United States of America          50
# 10776                     NaN  United States of America          55
# 10777                     NaN  United States of America          60
# 10778                     NaN  United States of America          65
# 10779                     NaN  United States of America          70
# 10780                     NaN  United States of America          75
# 10781                     NaN  United States of America          80
# 10782                     NaN  United States of America          85
# 10783                     NaN  United States of America          90
# 10784                     NaN  United States of America          95
# 10789                     NaN  United States of America          10
# 10790                     NaN  United States of America          15
# 10792                     NaN  United States of America          20
# 10793                     NaN  United States of America          25
# 10795                     NaN  United States of America          30
# 10796                     NaN  United States of America          35
# 10798                     NaN  United States of America          40
# 10799                     NaN  United States of America          45
# 10801                     NaN  United States of America          50
# 10802                     NaN  United States of America          55
# 10803                     NaN  United States of America          60
# 10804                     NaN  United States of America          65
# 10805                     NaN  United States of America          70
# 10806                     NaN  United States of America          75
# 10807                     NaN  United States of America          80
# 10808                     NaN  United States of America          85
# 10809                     NaN  United States of America          90
# 10810                     NaN  United States of America          95

# %%
# Calculate the Pearson correlation coefficient between deaths age 
# for age and average deaths for the year 2020
#age=year2020_df.iloc[:,1]
#deaths=year2020_df.iloc[:,2]
#correlation = st.pearsonr(age,deaths)
#print(f"The correlation between age and the average deaths is {round(correlation[0],2)}")

# %%
# Convert relevant date columns to float

year2020_df = year2020_df.astype({"newagerange": "float"})
year2020_df.dtypes
# Out:
# Year                        int64
# Cause                      object
# Age_Range                  object
# ISO_Code                   object
# Sex                        object
# Deaths                      int64
# Age_and_Sex_Population    float64
# Country                    object
# newagerange               float64
# dtype: object

# %%
# Linear regression on year 2020
linear_reg(year2020_df['newagerange'], year2020_df['Deaths'],(10, -10))
plt.xlabel('Age')
plt.ylabel('USA Intentional Self-Harm Deaths in 2020')
# Save the figure
plt.savefig("output_data/Fig2.png")
# Out:
# The r-value between newagerange and Deaths is -0.36

# %%
#Discussion about the linear relationship:  In the year 2020 Intentinal harm-self deaths have a none or very weak strength of correlation 
#negative  coorelation -0.36  that is to  say the deaths level does not much relate to the Age range.

# %%
gun_violence_data = Path("../Resources/gun_violence_us (1).csv")
gun_violence_df = pd.read_csv(gun_violence_data)
gun_violence_df.head()
# Out:
#   state  mortality_rate  ownership_rate
# 0    AL            16.7           0.489
# 1    AK            18.8           0.617
# 2    AZ            13.4           0.323
# 3    AR            16.4           0.579
# 4    CA             7.4           0.201

# %%
gun_violence_df.columns
# Out:
# Index(['state', 'mortality_rate', 'ownership_rate'], dtype='object')

# %%
data = {'State': gun_violence_df['state'],
        'Mortality Rate': gun_violence_df['mortality_rate'],
        'Gun Ownership': gun_violence_df['ownership_rate']}
df = pd.DataFrame(data)

# Set the width of the bars
bar_width = 0.35

# Set the positions of the bars on the x-axis
bar_positions1 = range(len(df))
bar_positions2 = [x + bar_width for x in bar_positions1]

# Create the bar graph
plt.bar(bar_positions1, df['Mortality Rate'], width=bar_width, label='Mortality Rate')
plt.bar(bar_positions2, df['Gun Ownership'], width=bar_width, label='Gun Ownership')

# Add labels and title
plt.xlabel('State')
plt.ylabel('Values')
plt.title('Bar Graph with Two Sets of Data')
plt.xticks([x + bar_width/2 for x in bar_positions1], df['State'])

# Add legend
plt.legend()

# Show the plot

# %%
data = {'State': gun_violence_df['state'],
        'Mortality Rate': gun_violence_df['mortality_rate'],
        'Gun Ownership': gun_violence_df['ownership_rate']}
df = pd.DataFrame(data)

# Plot the lines
plt.plot(df['State'], df['Mortality Rate'], label='Mortality Rate')
plt.plot(df['State'], df['Gun Ownership'], label='Gun Ownership')

# Add labels and title
plt.xlabel('State')
plt.ylabel('Value')
plt.title('Line Graph with Two Lines')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
mortality_rate_average = gun_violence_df['mortality_rate'].mean()
print(mortality_rate_average)
# Out:
# 11.354000000000001

# %%
ownership_rate_average = gun_violence_df['ownership_rate'].mean()
print(ownership_rate_average)
# Out:
# 0.33092000000000005

# %%
firearm_death_data = Path("../Resources/Firearm_suicide_homicide_dataset.csv")
firearm_death_df = pd.read_csv(firearm_death_data)
firearm_death_df.tail()
# Out:
#       year          state            division  total_population       fss  \
# 3646  2020       Virginia      South Atlantic         8590563.0  0.580350
# 3647  2020     Washington             Pacific         7693612.0  0.509901
# 3648  2020  West Virginia      South Atlantic         1784787.0  0.621469
# 3649  2020      Wisconsin  East North Central         5832655.0  0.510393
# 3650  2020        Wyoming            Mountain          582328.0  0.703297
#
#      homicide_rate firearm_homicide_rate nonfirearm_homicide_rate  \
# 3646   6.181201395           5.121899461              1.059301934
# 3647   4.185290342           2.742534976              1.442755366
# 3648   6.387316806           4.874531247              1.512785559
# 3649   5.726380182           4.337647264              1.388732918
# 3650    4.29311316           3.091041475              1.202071685
#
#       firearm_suicides  total_suicides  firearm_homicides  \
# 3646               697            1201              440.0
# 3647               618            1212              211.0
# 3648               220             354               87.0
# 3649               442             866              253.0
# 3650               128             182               18.0
#
#       nonfirearm_homicides  total_homicides  white_fss  nonwhite_fss  \
# 3646                  91.0              531   0.594540      0.514151
# 3647                 111.0              322   0.531191      0.363636
# 3648                  27.0              114   0.626113      0.529412
# 3649                  81.0              334   0.516169      0.435484
# 3650                   7.0               25   0.706215      0.600000
#
#       nextyearfss  nextyearnonwhitefss  nextyearwhitefss
# 3646          NaN                  NaN               NaN
# 3647          NaN                  NaN               NaN
# 3648          NaN                  NaN               NaN
# 3649          NaN                  NaN               NaN
# 3650          NaN                  NaN               NaN

# %%
#years_firearm_death_df = firearm_death_df.sort_values("year", ascending=False)
#years_firearm_death_df.head()

# %%
firearm_death_df.columns
# Out:
# Index(['year', 'state', 'division', 'total_population', 'fss', 'homicide_rate',
#        'firearm_homicide_rate', 'nonfirearm_homicide_rate', 'firearm_suicides',
#        'total_suicides', 'firearm_homicides', 'nonfirearm_homicides',
#        'total_homicides', 'white_fss', 'nonwhite_fss', 'nextyearfss',
#        'nextyearnonwhitefss', 'nextyearwhitefss'],
#       dtype='object')

# %%
firearm_death_df = firearm_death_df[['year', 'state', 'division', 'total_population', 'fss', 'homicide_rate',
       'firearm_homicide_rate', 'nonfirearm_homicide_rate', 'firearm_suicides',
       'total_suicides', 'firearm_homicides', 'nonfirearm_homicides',
       'total_homicides', 'white_fss', 'nonwhite_fss']]
firearm_death_df
# Out:
#       year          state            division  total_population       fss  \
# 0     1949        Alabama  East South Central         3004000.0  0.717949
# 1     1949        Arizona            Mountain          726000.0  0.575000
# 2     1949       Arkansas  West South Central         1835000.0  0.671053
# 3     1949     California             Pacific        10499000.0  0.382623
# 4     1949       Colorado            Mountain         1249000.0  0.551570
# ...    ...            ...                 ...               ...       ...
# 3646  2020       Virginia      South Atlantic         8590563.0  0.580350
# 3647  2020     Washington             Pacific         7693612.0  0.509901
# 3648  2020  West Virginia      South Atlantic         1784787.0  0.621469
# 3649  2020      Wisconsin  East North Central         5832655.0  0.510393
# 3650  2020        Wyoming            Mountain          582328.0  0.703297
#
#      homicide_rate firearm_homicide_rate nonfirearm_homicide_rate  \
# 0      14.28095872           7.822902796              6.458055925
# 1       5.64738292           3.168044077              2.479338843
# 2      7.901907357           4.141689373              3.760217984
# 3       4.61948757           1.857319745              2.762167826
# 4      5.044035228           3.442754203              1.601281025
# ...            ...                   ...                      ...
# 3646   6.181201395           5.121899461              1.059301934
# 3647   4.185290342           2.742534976              1.442755366
# 3648   6.387316806           4.874531247              1.512785559
# 3649   5.726380182           4.337647264              1.388732918
# 3650    4.29311316           3.091041475              1.202071685
#
#       firearm_suicides  total_suicides  firearm_homicides  \
# 0                  140             195              235.0
# 1                   46              80               23.0
# 2                  102             152               76.0
# 3                  709            1853              195.0
# 4                  123             223               43.0
# ...                ...             ...                ...
# 3646               697            1201              440.0
# 3647               618            1212              211.0
# 3648               220             354               87.0
# 3649               442             866              253.0
# 3650               128             182               18.0
#
#       nonfirearm_homicides  total_homicides  white_fss  nonwhite_fss
# 0                    194.0              429   0.708571      0.482655
# 1                     18.0               41   0.583333      0.800000
# 2                     69.0              145   0.664336      0.500000
# 3                    290.0              485   0.382187      0.777778
# 4                     20.0               63   0.559633      0.392405
# ...                    ...              ...        ...           ...
# 3646                  91.0              531   0.594540      0.514151
# 3647                 111.0              322   0.531191      0.363636
# 3648                  27.0              114   0.626113      0.529412
# 3649                  81.0              334   0.516169      0.435484
# 3650                   7.0               25   0.706215      0.600000
#
# [3651 rows x 15 columns]

# %%
# Load your dataset into a pandas DataFrame
#firearm_death_df = pd.read_csv(firearm_death_data)

# Filter the dataset for years 2015 to 2020
filtered_data = firearm_death_df[(firearm_death_df['year'] >= 2015) & (firearm_death_df['year'] <= 2020)]

# Group the filtered data by year and calculate the sum of firearm suicides and total suicides
grouped_data = filtered_data.groupby('year').agg({'firearm_suicides': 'sum', 'total_suicides': 'sum'}).reset_index()

# Create a side-by-side bar graph
labels = grouped_data['year']
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
bar1 = ax.bar(x - width/2, grouped_data['firearm_suicides'], width, label='Firearm Suicides', color='red')
bar2 = ax.bar(x + width/2, grouped_data['total_suicides'], width, label='Total Suicides', color='blue')

ax.set_xlabel('Year')
ax.set_ylabel('Number of Suicides')
ax.set_title('Comparison of Firearm Suicides to Total Suicides (2015-2020)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %%
#firearm_death_df = pd.read_csv(firearm_death_data)

# Filter the dataset for years 2015 to 2020
#filtered_data = firearm_death_df[(firearm_death_df['year'] >= 2015) & (firearm_death_df['year'] <= 2020)]

# Calculate the total firearm suicides and total suicides for the filtered years
total_firearm_suicides = filtered_data['firearm_suicides'].sum()
total_suicides = filtered_data['total_suicides'].sum()

# Create a pie chart
labels = ['Firearm Suicides', 'Non-Firearm Suicides']
sizes = [total_firearm_suicides, total_suicides - total_firearm_suicides]
colors = ['red', 'blue']

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Comparison of Firearm Suicides to Total Suicides (2015-2020)')
plt.show()

# %%
firearm_deaths = firearm_death_df['firearm_suicides']
total_suicides = firearm_death_df['total_suicides']

plt.figure(figsize=(10, 6))
plt.scatter(firearm_deaths, total_suicides, color='blue', alpha=0.5)
plt.title('Firearm Deaths vs. Total Suicides')
plt.xlabel('Firearm Deaths')
plt.ylabel('Total Suicides')
plt.grid(True)
plt.show()

# %%
correlation_coefficient, p_value = pearsonr(firearm_deaths, total_suicides)
print(f"Pearson Correlation Coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson Correlation Coefficient: 0.952390378750439
# P-value: 0.0

# %%
# Create a boxplot to compare means
#filtered_data.replace(0, pd.NA, inplace=True)
filtered_data2 = filtered_data.dropna() 
filtered_data2.boxplot("firearm_suicides", by="year", figsize=(20, 10))
# Out:
# <Axes: title={'center': 'firearm_suicides'}, xlabel='year'>

# %%
 # Extract individual groups
group0 = filtered_data2[filtered_data2["year"] == 2015]["firearm_suicides"]
group1 = filtered_data2[filtered_data2["year"] == 2016]["firearm_suicides"]
group2 = filtered_data2[filtered_data2["year"] == 2017]["firearm_suicides"]
group3 = filtered_data2[filtered_data2["year"] == 2018]["firearm_suicides"]
group4 = filtered_data2[filtered_data2["year"] == 2019]["firearm_suicides"]
group5 = filtered_data2[filtered_data2["year"] == 2020]["firearm_suicides"]

# %%
 # Perform the ANOVA
stats.f_oneway(group0, group1, group2, group3, group4, group5)
# Out:
# F_onewayResult(statistic=0.1549235600888832, pvalue=0.978414786675637)

# %%
states= Path("../Resources/states.csv")
states_df = pd.read_csv(states)
states_df
# Out:
#                    State Abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# 24            New Jersey           NJ
# 25            New Mexico           NM
# 26              New York           NY
# 27        North Carolina           NC
# 28          North Dakota           ND
# 29                  Ohio           OH
# 30              Oklahoma           OK
# 31                Oregon           OR
# 32              Maryland           MD
# 33         Massachusetts           MA
# 34              Michigan           MI
# 35             Minnesota           MN
# 36           Mississippi           MS
# 37              Missouri           MO
# 38          Pennsylvania           PA
# 39          Rhode Island           RI
# 40        South Carolina           SC
# 41          South Dakota           SD
# 42             Tennessee           TN
# 43                 Texas           TX
# 44                  Utah           UT
# 45               Vermont           VT
# 46              Virginia           VA
# 47            Washington           WA
# 48         West Virginia           WV
# 49             Wisconsin           WI
# 50               Wyoming           WY

# %%
states_df = states_df.rename(columns={"State": "state"})

# %%
mergedstates_df =firearm_death_df.merge(states_df, on ='state')
mergedstates_df
# Out:
#       year    state            division  total_population       fss  \
# 0     1949  Alabama  East South Central         3004000.0  0.717949
# 1     1950  Alabama  East South Central         3061743.0  0.688995
# 2     1951  Alabama  East South Central         3082242.7  0.710383
# 3     1952  Alabama  East South Central         3102742.4  0.728643
# 4     1953  Alabama  East South Central         3123242.1  0.694690
# ...    ...      ...                 ...               ...       ...
# 3646  2016   Hawaii             Pacific         1428557.0  0.212644
# 3647  2017   Hawaii             Pacific         1427538.0  0.132159
# 3648  2018   Hawaii             Pacific         1420491.0  0.170455
# 3649  2019   Hawaii             Pacific         1415872.0  0.183036
# 3650  2020   Hawaii             Pacific         1407006.0  0.168478
#
#      homicide_rate firearm_homicide_rate nonfirearm_homicide_rate  \
# 0      14.28095872           7.822902796              6.458055925
# 1      14.10961011           8.165283631              5.944326483
# 2      11.48514359           6.359006058              5.126137536
# 3      13.05296888           7.058272063               5.99469682
# 4      12.03877215           6.403602206              5.635169941
# ...            ...                   ...                      ...
# 3646   2.730027573           1.540015554              1.190012019
# 3647   2.451773613           0.280202699              2.171570914
# 3648   2.815927732           1.407963866              1.407963866
# 3649   2.471974868           0.988789947              1.483184921
# 3650   3.269353507           1.137166437               2.13218707
#
#       firearm_suicides  total_suicides  firearm_homicides  \
# 0                  140             195              235.0
# 1                  144             209              250.0
# 2                  130             183              196.0
# 3                  145             199              219.0
# 4                  157             226              200.0
# ...                ...             ...                ...
# 3646                37             174               22.0
# 3647                30             227                4.0
# 3648                30             176               20.0
# 3649                41             224               14.0
# 3650                31             184               16.0
#
#       nonfirearm_homicides  total_homicides  white_fss  nonwhite_fss  \
# 0                    194.0              429   0.708571      0.482655
# 1                    182.0              432   0.672131      0.807692
# 2                    158.0              354   0.737805      0.473684
# 3                    186.0              405   0.732558      0.703704
# 4                    176.0              376   0.686567      0.703704
# ...                    ...              ...        ...           ...
# 3646                  17.0               39   0.178571      0.180180
# 3647                  31.0               35   0.135135      0.090090
# 3648                  20.0               40   0.225352      0.099010
# 3649                  21.0               35   0.182796      0.157480
# 3650                  30.0               46   0.240964      0.110000
#
#      Abbreviation
# 0              AL
# 1              AL
# 2              AL
# 3              AL
# 4              AL
# ...           ...
# 3646           HI
# 3647           HI
# 3648           HI
# 3649           HI
# 3650           HI
#
# [3651 rows x 16 columns]

# %%
average_firearmdeath = mergedstates_df.groupby("Abbreviation")['firearm_suicides'].mean()
avg_firearmdeath_df = pd.DataFrame(average_firearmdeath)
avg_firearmdeath_df = avg_firearmdeath_df.reset_index()
avg_firearmdeath_df
# Out:
#    Abbreviation  firearm_suicides
# 0            AK         66.016129
# 1            AL        339.458333
# 2            AR        206.652778
# 3            AZ        370.972222
# 4            CA       1468.041667
# 5            CO        305.180556
# 6            CT         98.666667
# 7            DC         17.458333
# 8            DE         35.763889
# 9            FL        952.430556
# 10           GA        535.222222
# 11           HI         29.491803
# 12           IA        172.055556
# 13           ID        112.041667
# 14           IL        462.083333
# 15           IN        377.486111
# 16           KS        189.263889
# 17           KY        329.805556
# 18           LA        322.500000
# 19           MA        125.541667
# 20           MD        222.402778
# 21           ME         87.875000
# 22           MI        520.541667
# 23           MN        222.055556
# 24           MO        402.013889
# 25           MS        200.430556
# 26           MT        100.972222
# 27           NC        524.736111
# 28           ND         42.902778
# 29           NE         98.097222
# 30           NH         64.972222
# 31           NJ        170.472222
# 32           NM        152.500000
# 33           NV        164.222222
# 34           NY        429.555556
# 35           OH        641.611111
# 36           OK        273.861111
# 37           OR        251.194444
# 38           PA        660.055556
# 39           RI         23.888889
# 40           SC        271.472222
# 41           SD         52.708333
# 42           TN        429.875000
# 43           TX       1212.902778
# 44           UT        141.888889
# 45           VA        460.472222
# 46           VT         45.444444
# 47           WA        338.486111
# 48           WI        279.375000
# 49           WV        168.875000
# 50           WY         60.986111

# %%
stateabrv_df = gun_violence_df.rename(columns={"state": "Abbreviation"})

# %%
gun_violence_df
# Out:
#    state  mortality_rate  ownership_rate
# 0     AL            16.7           0.489
# 1     AK            18.8           0.617
# 2     AZ            13.4           0.323
# 3     AR            16.4           0.579
# 4     CA             7.4           0.201
# 5     CO            12.1           0.343
# 6     CT             4.9           0.166
# 7     DE            11.1           0.052
# 8     FL            11.5           0.325
# 9     GA            13.7           0.316
# 10    HI             2.6           0.451
# 11    ID            13.1           0.569
# 12    IL             9.0           0.262
# 13    IN            12.3           0.338
# 14    IA             7.4           0.338
# 15    KS            11.3           0.322
# 16    KY            13.8           0.424
# 17    LA            18.9           0.445
# 18    ME             9.3           0.226
# 19    MD             9.0           0.207
# 20    MA             3.2           0.226
# 21    MI            11.1           0.288
# 22    MN             6.6           0.367
# 23    MS            18.0           0.428
# 24    MO            15.2           0.271
# 25    MT            15.8           0.523
# 26    NE             9.4           0.198
# 27    NV            14.7           0.375
# 28    NH             8.6           0.144
# 29    NJ             5.3           0.113
# 30    NM            15.8           0.499
# 31    NY             4.2           0.103
# 32    NC            11.7           0.287
# 33    ND            12.1           0.479
# 34    OH            10.3           0.196
# 35    OK            15.6           0.312
# 36    OR            11.7           0.266
# 37    PA            10.5           0.271
# 38    RI             2.9           0.058
# 39    SC            15.5           0.444
# 40    SD            10.3           0.350
# 41    TN            14.7           0.394
# 42    TX            10.6           0.357
# 43    UT            12.3           0.319
# 44    VT            10.3           0.288
# 45    VA            10.3           0.293
# 46    WA             9.6           0.277
# 47    WV            14.5           0.542
# 48    WI             8.2           0.347
# 49    WY            16.0           0.538

# %%
merged_df = stateabrv_df.merge(avg_firearmdeath_df, on='Abbreviation')

# %%
merged_df
# Out:
#    Abbreviation  mortality_rate  ownership_rate  firearm_suicides
# 0            AL            16.7           0.489        339.458333
# 1            AK            18.8           0.617         66.016129
# 2            AZ            13.4           0.323        370.972222
# 3            AR            16.4           0.579        206.652778
# 4            CA             7.4           0.201       1468.041667
# 5            CO            12.1           0.343        305.180556
# 6            CT             4.9           0.166         98.666667
# 7            DE            11.1           0.052         35.763889
# 8            FL            11.5           0.325        952.430556
# 9            GA            13.7           0.316        535.222222
# 10           HI             2.6           0.451         29.491803
# 11           ID            13.1           0.569        112.041667
# 12           IL             9.0           0.262        462.083333
# 13           IN            12.3           0.338        377.486111
# 14           IA             7.4           0.338        172.055556
# 15           KS            11.3           0.322        189.263889
# 16           KY            13.8           0.424        329.805556
# 17           LA            18.9           0.445        322.500000
# 18           ME             9.3           0.226         87.875000
# 19           MD             9.0           0.207        222.402778
# 20           MA             3.2           0.226        125.541667
# 21           MI            11.1           0.288        520.541667
# 22           MN             6.6           0.367        222.055556
# 23           MS            18.0           0.428        200.430556
# 24           MO            15.2           0.271        402.013889
# 25           MT            15.8           0.523        100.972222
# 26           NE             9.4           0.198         98.097222
# 27           NV            14.7           0.375        164.222222
# 28           NH             8.6           0.144         64.972222
# 29           NJ             5.3           0.113        170.472222
# 30           NM            15.8           0.499        152.500000
# 31           NY             4.2           0.103        429.555556
# 32           NC            11.7           0.287        524.736111
# 33           ND            12.1           0.479         42.902778
# 34           OH            10.3           0.196        641.611111
# 35           OK            15.6           0.312        273.861111
# 36           OR            11.7           0.266        251.194444
# 37           PA            10.5           0.271        660.055556
# 38           RI             2.9           0.058         23.888889
# 39           SC            15.5           0.444        271.472222
# 40           SD            10.3           0.350         52.708333
# 41           TN            14.7           0.394        429.875000
# 42           TX            10.6           0.357       1212.902778
# 43           UT            12.3           0.319        141.888889
# 44           VT            10.3           0.288         45.444444
# 45           VA            10.3           0.293        460.472222
# 46           WA             9.6           0.277        338.486111
# 47           WV            14.5           0.542        168.875000
# 48           WI             8.2           0.347        279.375000
# 49           WY            16.0           0.538         60.986111

# %%
plt.figure(figsize=(12, 8))
plt.scatter(merged_df['Abbreviation'], merged_df['ownership_rate'], s=merged_df['firearm_suicides']*10, alpha=0.5)
plt.title('Ownership Rate vs. Firearm Suicides by State')
plt.xlabel('State')
plt.ylabel('Ownership Rate')
plt.colorbar(label='Firearm Suicides')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
#plt.figure(figsize=(12, 8))

# Define the width of each bar
#bar_width = 0.35

# Get the states, ownership rate, and firearm suicides data
#states = merged_df['abbreviation']
#ownership_rate = merged_df['ownership_rate']
#firearm_suicides = merged_df['firearm_suicides']

# Plot the grouped bar chart
#plt.bar(states, ownership_rate, width=bar_width, label='Ownership Rate')
#plt.bar(states, firearm_suicides, width=bar_width, label='Firearm Suicides', alpha=0.5)

#plt.xlabel('State')
#plt.ylabel('Rate')
#plt.title('Ownership Rate vs. Firearm Suicides by State')
#plt.xticks(rotation=45)
#plt.legend()
#plt.grid(axis='y')
#plt.tight_layout()
#plt.show()

# %%
wrk = Path("../Resources/average_hours_worked_per_week.csv")
House_hold = Path("../Resources/Household.income 2.csv")
suicide = Path("../Resources/2015_suicide_rates.csv")
sal = Path("../Resources/data-tableusa.csv")
salperstate = Path("../Resources/h08.csv")

wrk_df = pd.read_csv(wrk, encoding="UTF-8")
House_hold_df = pd.read_csv(House_hold, encoding="UTF-8")
suicide_df = pd.read_csv(suicide, encoding="UTF-8")
#wrk_df.head()
House_hold_df.head()
#Annual_hours_df.head()
salarybyamount_df = pd.read_csv(sal, encoding="UTF-8")
salarybystate_df = pd.read_csv(salperstate, encoding="UTF-8")
salarybyamount_df.head()#actually suicide deaths per year
# Out:
#    YEAR STATE  RATE DEATHS                                       URL
# 0  2021    AL  15.8    827     /nchs/pressroom/states/alabama/al.htm
# 1  2021    AK  30.8    220      /nchs/pressroom/states/alaska/ak.htm
# 2  2021    AZ  19.5   1475     /nchs/pressroom/states/arizona/az.htm
# 3  2021    AR  20.6    618    /nchs/pressroom/states/arkansas/ar.htm
# 4  2021    CA  10.1   4148  /nchs/pressroom/states/california/ca.htm

# %%
# Selecting specific columns "Country", "Time", and "Value"
clean_wrk_df = wrk_df.iloc[11:16] 
clean_house_hold_df = House_hold_df[["State","2020 (41)","2019","2018","2017","2016"]]
columns = "State","2020","2019","2018","2017","2016"
clean_house_hold_df.columns = columns

clean_house_hold_df = clean_house_hold_df.drop(clean_house_hold_df.index[0])
clean_house_hold_df = clean_house_hold_df.drop(clean_house_hold_df.index[0])
clean_house_hold_df = clean_house_hold_df.set_index(clean_house_hold_df.columns[0])
clean_house_hold_df[["2020","2019","2018","2017","2016"]] = clean_house_hold_df[["2020","2019","2018","2017","2016"]].astype(float)
column = [["2020","2019","2018","2017","2016"]]

clean_house_hold_df.head()

#clean_house_hold_df = clean_house_hold_df.set_index(clean_house_hold_df.columns[0])
# Displaying the new DataFrame
clean_wrk_df.tail()
clean_house_hold_df.head()
# Out:
#                2020     2019     2018     2017     2016
# State
# Alabama     54690.0  56200.0  49940.0  51110.0  47220.0
# Alaska      74750.0  78390.0  68730.0  72230.0  75720.0
# Arizona     67090.0  70670.0  62280.0  61130.0  57100.0
# Arkansas    50780.0  54540.0  49780.0  48830.0  45910.0
# California  77650.0  78110.0  70490.0  69760.0  66640.0

# %%
print(clean_wrk_df.columns)
# Out:
# Index(['U.S. average hours worked per week 2007-2022', 'Unnamed: 1'], dtype='object')

# %%
clean_wrk_df.columns = ["Year", "Average Weekly Worked Hours"]
clean_wrk_df = clean_wrk_df.reset_index()

clean_wrk_df
# Out:
#    index  Year  Average Weekly Worked Hours
# 0     11  2016                         34.4
# 1     12  2017                         34.4
# 2     13  2018                         34.5
# 3     14  2019                         34.4
# 4     15  2020                         34.6

# %%
# Assuming 'column' is a 1D array or list containing the years
avg_hrs_wrk = pd.DataFrame({
    "Year": ["2016","2017", "2018", "2019", "2020"],
    "Average Household Income ($)": clean_wrk_df["Average Weekly Worked Hours"]
})

# %%
average_income_16 = float("{:.2f}".format(clean_house_hold_df['2016'].mean()))
average_income_20 = float("{:.2f}".format(clean_house_hold_df['2020'].mean()))
average_income_19 = float("{:.2f}".format(clean_house_hold_df['2019'].mean()))
average_income_18 = float("{:.2f}".format(clean_house_hold_df['2018'].mean()))
average_income_17 = float("{:.2f}".format(clean_house_hold_df['2017'].mean()))

# %%
print(type(average_income_16))
print(type(average_income_20))
print(type(average_income_19))
print(type(average_income_18))
print(type(average_income_17))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
us_average_income = pd.DataFrame({
    "Year": ["2016","2017", "2018", "2019", "2020"],
    "Average Household Income ($)": [average_income_16, average_income_17, average_income_18, average_income_19, average_income_20]
})

# %%
us_average_income
# Out:
#    Year  Average Household Income ($)
# 0  2016                      59179.61
# 1  2017                      61640.59
# 2  2018                      64411.18
# 3  2019                      69720.59
# 4  2020                      68660.39

# %%
# Assuming clean_wrk_df['Year'] and clean_wrk_df['Average Weekly Worked Hours'] are DataFrame columns
# Convert the numpy array to a list
year_list = clean_wrk_df['Year']

# Plot the data
plt.plot(avg_hrs_wrk["Year"], avg_hrs_wrk["Average Household Income ($)"], marker='o', linestyle='-')

# Set y-axis limits and ticks


# Add labels and title
plt.xlabel('Year')
plt.ylabel('Average Weekly Worked Hours')
plt.title('Average Weekly Worked Hours Over Years')
plt.savefig('../Visuals/average_weekly_hours_worked.png')
# Show the plot
plt.show()

# %%
# Plot the data
plt.plot(us_average_income['Year'], us_average_income['Average Household Income ($)'], marker='o', linestyle='-')

# Set y-axis limits and ticks
plt.ylim(55000, 80000)
plt.yticks(range(55000, 80001, 5000))

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Average Household Income ($)')
plt.title('Average Household Income Over 5 Years')
plt.savefig('../Visuals/average_household_income.png')
# Show the plot
plt.show()

# %%
print(suicide_df.columns)
suicide_df
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')
#     LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value Flag Codes
# 0        AUS   SUICIDE     TOT  100000PER         A  2015   13.2        NaN
# 1        AUS   SUICIDE     TOT  100000PER         A  2016   12.2        NaN
# 2        AUS   SUICIDE     TOT  100000PER         A  2017   13.6        NaN
# 3        AUS   SUICIDE     TOT  100000PER         A  2018   13.0        NaN
# 4        AUS   SUICIDE     TOT  100000PER         A  2019   13.5        NaN
# ..       ...       ...     ...        ...       ...   ...    ...        ...
# 232      ROU   SUICIDE     TOT  100000PER         A  2015   10.9        NaN
# 233      ROU   SUICIDE     TOT  100000PER         A  2016    9.6        NaN
# 234      ROU   SUICIDE     TOT  100000PER         A  2017    9.4        NaN
# 235      ROU   SUICIDE     TOT  100000PER         A  2018    9.5        NaN
# 236      ROU   SUICIDE     TOT  100000PER         A  2019    8.6        NaN
#
# [237 rows x 8 columns]

# %%
suicide_df = suicide_df[["LOCATION", "INDICATOR", "SUBJECT", "MEASURE", "TIME", "Value"]]
suicide_df.columns = ["Country","Indicator", "Subject","Measure", "Year", "Value"]
suicide_df.head()
# Out:
#   Country Indicator Subject    Measure  Year  Value
# 0     AUS   SUICIDE     TOT  100000PER  2015   13.2
# 1     AUS   SUICIDE     TOT  100000PER  2016   12.2
# 2     AUS   SUICIDE     TOT  100000PER  2017   13.6
# 3     AUS   SUICIDE     TOT  100000PER  2018   13.0
# 4     AUS   SUICIDE     TOT  100000PER  2019   13.5

# %%
usa_suicide_rates = suicide_df[suicide_df["Country"] == "USA"]
usa_suicide_rates.reset_index(drop=True, inplace=True)

usa_suicide_rates.head()
# Out:
#   Country Indicator Subject    Measure  Year  Value
# 0     USA   SUICIDE     TOT  100000PER  2015   14.0
# 1     USA   SUICIDE     TOT  100000PER  2016   14.2
# 2     USA   SUICIDE     TOT  100000PER  2017   14.8
# 3     USA   SUICIDE     TOT  100000PER  2018   15.0
# 4     USA   SUICIDE     TOT  100000PER  2019   14.7

# %%
# Plot the data
plt.plot(usa_suicide_rates['Year'], usa_suicide_rates['Value'], marker='o', linestyle='-')

# Set y-axis limits and ticks
plt.ylim(13, 16)
#plt.yticks(range(55000, 80001, 5000))

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Suicides per 100k Population')
plt.title('USA Suicide rates Over 5 Years')
plt.savefig('../Visuals/usa_suicide_rates.png')
# Show the plot
plt.show()

# %%
# Check the data types of columns in suicide_df
suicide_df_dtypes = suicide_df.dtypes
print(suicide_df_dtypes)
# Out:
# Country       object
# Indicator     object
# Subject       object
# Measure       object
# Year           int64
# Value        float64
# dtype: object

# %%
world_suicide_df = suicide_df[suicide_df['Country'] != 'USA']
world_suicide_df.reset_index(drop=True, inplace=True)
world_suicide_df.head()
# Out:
#   Country Indicator Subject    Measure  Year  Value
# 0     AUS   SUICIDE     TOT  100000PER  2015   13.2
# 1     AUS   SUICIDE     TOT  100000PER  2016   12.2
# 2     AUS   SUICIDE     TOT  100000PER  2017   13.6
# 3     AUS   SUICIDE     TOT  100000PER  2018   13.0
# 4     AUS   SUICIDE     TOT  100000PER  2019   13.5

# %%
# Check the data types of columns
print(world_suicide_df.dtypes)
# Out:
# Country       object
# Indicator     object
# Subject       object
# Measure       object
# Year           int64
# Value        float64
# dtype: object

# %%
# Group the DataFrame by the "Year" column and calculate the mean
world_suicide_avg = world_suicide_df[["Year","Value"]]
#average_by_year = suicide_df.groupby("Year").mean()

# Display the resulting DataFrame
#print(average_by_year)
world_suicide_avg
# Out:
#      Year  Value
# 0    2015   13.2
# 1    2016   12.2
# 2    2017   13.6
# 3    2018   13.0
# 4    2019   13.5
# ..    ...    ...
# 226  2015   10.9
# 227  2016    9.6
# 228  2017    9.4
# 229  2018    9.5
# 230  2019    8.6
#
# [231 rows x 2 columns]

# %%
# Calculate the average suicide rate for all countries together by year
average_by_year_w = world_suicide_avg.groupby(["Year"]).mean()
average_by_year_w.reset_index(inplace=True)


# Display the resulting DataFrame
average_by_year_w.head()
# Out:
#    Year      Value
# 0  2015  11.390698
# 1  2016  10.669767
# 2  2017  10.735000
# 3  2018  10.507895
# 4  2019  10.494595

# %%
# Plot the data
plt.plot(average_by_year_w["Year"], average_by_year_w['Value'], marker='o', linestyle='-')

# Set y-axis limits and ticks
plt.ylim(10, 16)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Suicides per 100k Population')
plt.title('Average Suicide Rate Over Years')
plt.savefig('../Visuals/average_world_suicide_rate_comparison.png')
# Show the plot
plt.show()

# %%
# Plot the data for average suicide rate
plt.plot(average_by_year_w["Year"], average_by_year_w['Value'], marker='o', linestyle='-', label='World')

# Plot the data for USA suicide rate
plt.plot(usa_suicide_rates['Year'], usa_suicide_rates['Value'], marker='o', linestyle='-', label='USA')

# Set y-axis limits and ticks
plt.ylim(10, 16)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Suicides per 100k Population')
plt.title('Average Suicide Rate Over Years')

# Add legend
plt.legend()
plt.savefig('../Visuals/suicide_rate_comparison.png')
# Show the plot
plt.show()

# %%
salarybyamount_df = salarybyamount_df.iloc[:, :-1]

# Alternatively, you can use the drop method
# df = df.drop(df.columns[-1], axis=1)

# Display the DataFrame after deleting the last column
filtered_df = salarybyamount_df[(salarybyamount_df['YEAR'] >= 2015) & (salarybyamount_df['YEAR'] <= 2020)]

print(filtered_df)
# Out:
#      YEAR STATE  RATE DEATHS
# 50   2020    AL  16.0    793
# 51   2020    AK  27.5    204
# 52   2020    AZ  17.6   1363
# 53   2020    AR  19.0    583
# 54   2020    CA  10.0   4144
# ..    ...   ...   ...    ...
# 345  2015    VA  12.7  1,118
# 346  2015    WA  15.4  1,137
# 347  2015    WV  17.4    340
# 348  2015    WI  14.7    877
# 349  2015    WY  28.0    157
#
# [300 rows x 4 columns]

# %%
filtered_df = salarybyamount_df[(salarybyamount_df['YEAR'] >= 2015) & (salarybyamount_df['YEAR'] <= 2020)]
filtered_df
# Out:
#      YEAR STATE  RATE DEATHS
# 50   2020    AL  16.0    793
# 51   2020    AK  27.5    204
# 52   2020    AZ  17.6   1363
# 53   2020    AR  19.0    583
# 54   2020    CA  10.0   4144
# ..    ...   ...   ...    ...
# 345  2015    VA  12.7  1,118
# 346  2015    WA  15.4  1,137
# 347  2015    WV  17.4    340
# 348  2015    WI  14.7    877
# 349  2015    WY  28.0    157
#
# [300 rows x 4 columns]

# %%
print(filtered_df.info())
columns_to_convert1 = ["DEATHS"]
filtered_df[columns_to_convert1] = filtered_df[columns_to_convert1].apply(pd.to_numeric, errors='coerce')
print(filtered_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 50 to 349
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEAR    300 non-null    int64
#  1   STATE   300 non-null    object
#  2   RATE    300 non-null    float64
#  3   DEATHS  300 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 50 to 349
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEAR    300 non-null    int64
#  1   STATE   300 non-null    object
#  2   RATE    300 non-null    float64
#  3   DEATHS  250 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 11.7+ KB
# None

# %%
salarybystate_df
# Out:
#     Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61  \
# 0    Table H-8.  Median Household Income by State: ...
# 1    (Households as of March of the following year....
# 2                                      CURRENT DOLLARS
# 3                                                State
# 4                                                  NaN
# ..                                                 ...
# 110                                          Wisconsin
# 111                                            Wyoming
# 112  Source: U.S. Bureau of the Census, Current Pop...
# 113  Footnotes are available at <www.census.gov/top...
# 114                                                NaN
#
#          Unnamed: 1       Unnamed: 2      Unnamed: 3       Unnamed: 4  \
# 0               NaN              NaN             NaN              NaN
# 1               NaN              NaN             NaN              NaN
# 2               NaN              NaN             NaN              NaN
# 3              2020              NaN            2019              NaN
# 4    Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
# ..              ...              ...             ...              ...
# 110          62,629            2,039          65,029            2,979
# 111          62,539            3,892          60,987            3,262
# 112             NaN              NaN             NaN              NaN
# 113             NaN              NaN             NaN              NaN
# 114             NaN              NaN             NaN              NaN
#
#          Unnamed: 5       Unnamed: 6      Unnamed: 7       Unnamed: 8  \
# 0               NaN              NaN             NaN              NaN
# 1               NaN              NaN             NaN              NaN
# 2               NaN              NaN             NaN              NaN
# 3              2018              NaN            2017              NaN
# 4    Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
# ..              ...              ...             ...              ...
# 110          64,998            3,763          62,593            1,931
# 111          59,247            3,210          60,513            3,267
# 112             NaN              NaN             NaN              NaN
# 113             NaN              NaN             NaN              NaN
# 114             NaN              NaN             NaN              NaN
#
#          Unnamed: 9  ...     Unnamed: 65      Unnamed: 66     Unnamed: 67  \
# 0               NaN  ...             NaN              NaN             NaN
# 1               NaN  ...             NaN              NaN             NaN
# 2               NaN  ...             NaN              NaN             NaN
# 3              2016  ...            1988              NaN       1987 (21)
# 4    Median\nincome  ...  Median\nincome  Standard\nerror  Median\nincome
# ..              ...  ...             ...              ...             ...
# 110          58,745  ...          60,525            2,001          55,913
# 111          64,575  ...          54,066            2,241          58,502
# 112             NaN  ...             NaN              NaN             NaN
# 113             NaN  ...             NaN              NaN             NaN
# 114             NaN  ...             NaN              NaN             NaN
#
#          Unnamed: 68     Unnamed: 69      Unnamed: 70     Unnamed: 71  \
# 0                NaN             NaN              NaN             NaN
# 1                NaN             NaN              NaN             NaN
# 2                NaN             NaN              NaN             NaN
# 3                NaN            1986              NaN       1985 (20)
# 4    Standard\nerror  Median\nincome  Standard\nerror  Median\nincome
# ..               ...             ...              ...             ...
# 110            2,990          57,970            1,761          51,879
# 111            3,092          51,673            1,893          49,279
# 112              NaN             NaN              NaN             NaN
# 113              NaN             NaN              NaN             NaN
# 114              NaN             NaN              NaN             NaN
#
#          Unnamed: 72     Unnamed: 73      Unnamed: 74
# 0                NaN             NaN              NaN
# 1                NaN             NaN              NaN
# 2                NaN             NaN              NaN
# 3                NaN       1984 (19)              NaN
# 4    Standard\nerror  Median\nincome  Standard\nerror
# ..               ...             ...              ...
# 110            2,591          47,882            1,895
# 111            2,341          54,976            1,687
# 112              NaN             NaN              NaN
# 113              NaN             NaN              NaN
# 114              NaN             NaN              NaN
#
# [115 rows x 75 columns]

# %%
salarybystate_df = salarybystate_df.iloc[6:111, :13]
salarybystate_df
# Out:
#     Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61  \
# 6                                              Alabama
# 7                                               Alaska
# 8                                              Arizona
# 9                                             Arkansas
# 10                                          California
# ..                                                 ...
# 106                                            Vermont
# 107                                           Virginia
# 108                                         Washington
# 109                                      West Virginia
# 110                                          Wisconsin
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 6       49,936      2,423     50,865      1,094     51,113        845
# 7       68,734      3,390     77,987      3,718     72,231      2,719
# 8       62,283      2,291     59,700      2,689     61,125      2,642
# 9       49,781      2,108     49,751      2,491     48,829      2,642
# 10      70,489      1,233     70,038      1,576     69,759      1,452
# ..         ...        ...        ...        ...        ...        ...
# 106     70,066      2,350     65,234      3,389     65,360      3,209
# 107     77,151      3,086     72,537      3,898     73,031      3,356
# 108     79,726      3,025     73,284      2,176     77,256      3,388
# 109     50,573      1,337     48,102      1,308     46,499      1,521
# 110     62,629      2,039     65,029      2,979     64,998      3,763
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 6       47,221      2,301     44,509       3,419      42,278       1,529
# 7       75,723      4,086     75,112       3,485      67,629       3,153
# 8       57,100      1,971     52,248       2,008      49,254       2,304
# 9       45,907      2,165     42,798       1,572      44,922       2,546
# 10      66,637      1,075     63,636       1,711      60,487         894
# ..         ...        ...        ...         ...         ...         ...
# 106     63,660      1,427     63,058       2,779      64,455       3,289
# 107     69,535      2,549     65,169       2,585      70,239       3,128
# 108     73,573      2,189     71,271       3,448      62,714       2,330
# 109     46,412      2,087     45,389       3,320      41,993       2,330
# 110     62,593      1,931     58,745       1,576      61,665       2,287
#
# [105 rows x 13 columns]

# %%
new_column_names = ['State', '2020 median', '2020 standard error', '2019 median', '2019 standard error','2018 median', '2018 standard error','2017 median', '2017 standard error','2016 median', '2016 standard error','2015 median', '2015 standard error',]

# Rename the columns
salarybystate_df.columns = new_column_names

# %%
salarybystate_df
salarybystate_df = salarybystate_df.reset_index(drop=True)
salarybystate_df
# Out:
#              State 2020 median 2020 standard error 2019 median  \
# 0          Alabama      49,936               2,423      50,865
# 1           Alaska      68,734               3,390      77,987
# 2          Arizona      62,283               2,291      59,700
# 3         Arkansas      49,781               2,108      49,751
# 4       California      70,489               1,233      70,038
# ..             ...         ...                 ...         ...
# 100        Vermont      70,066               2,350      65,234
# 101       Virginia      77,151               3,086      72,537
# 102     Washington      79,726               3,025      73,284
# 103  West Virginia      50,573               1,337      48,102
# 104      Wisconsin      62,629               2,039      65,029
#
#     2019 standard error 2018 median 2018 standard error 2017 median  \
# 0                 1,094      51,113                 845      47,221
# 1                 3,718      72,231               2,719      75,723
# 2                 2,689      61,125               2,642      57,100
# 3                 2,491      48,829               2,642      45,907
# 4                 1,576      69,759               1,452      66,637
# ..                  ...         ...                 ...         ...
# 100               3,389      65,360               3,209      63,660
# 101               3,898      73,031               3,356      69,535
# 102               2,176      77,256               3,388      73,573
# 103               1,308      46,499               1,521      46,412
# 104               2,979      64,998               3,763      62,593
#
#     2017 standard error 2016 median 2016 standard error 2015 median  \
# 0                 2,301      44,509               3,419      42,278
# 1                 4,086      75,112               3,485      67,629
# 2                 1,971      52,248               2,008      49,254
# 3                 2,165      42,798               1,572      44,922
# 4                 1,075      63,636               1,711      60,487
# ..                  ...         ...                 ...         ...
# 100               1,427      63,058               2,779      64,455
# 101               2,549      65,169               2,585      70,239
# 102               2,189      71,271               3,448      62,714
# 103               2,087      45,389               3,320      41,993
# 104               1,931      58,745               1,576      61,665
#
#     2015 standard error
# 0                 1,529
# 1                 3,153
# 2                 2,304
# 3                 2,546
# 4                   894
# ..                  ...
# 100               3,289
# 101               3,128
# 102               2,330
# 103               2,330
# 104               2,287
#
# [105 rows x 13 columns]

# %%
newsalarybystate_df = salarybystate_df[["State", "2020 median", "2019 median", "2018 median", "2017 median", "2016 median", "2015 median"]]
newsalarybystate_df
# Out:
#              State 2020 median 2019 median 2018 median 2017 median  \
# 0          Alabama      49,936      50,865      51,113      47,221
# 1           Alaska      68,734      77,987      72,231      75,723
# 2          Arizona      62,283      59,700      61,125      57,100
# 3         Arkansas      49,781      49,751      48,829      45,907
# 4       California      70,489      70,038      69,759      66,637
# ..             ...         ...         ...         ...         ...
# 100        Vermont      70,066      65,234      65,360      63,660
# 101       Virginia      77,151      72,537      73,031      69,535
# 102     Washington      79,726      73,284      77,256      73,573
# 103  West Virginia      50,573      48,102      46,499      46,412
# 104      Wisconsin      62,629      65,029      64,998      62,593
#
#     2016 median 2015 median
# 0        44,509      42,278
# 1        75,112      67,629
# 2        52,248      49,254
# 3        42,798      44,922
# 4        63,636      60,487
# ..          ...         ...
# 100      63,058      64,455
# 101      65,169      70,239
# 102      71,271      62,714
# 103      45,389      41,993
# 104      58,745      61,665
#
# [105 rows x 7 columns]

# %%
print(newsalarybystate_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        104 non-null    object
#  1   2020 median  104 non-null    object
#  2   2019 median  104 non-null    object
#  3   2018 median  104 non-null    object
#  4   2017 median  104 non-null    object
#  5   2016 median  104 non-null    object
#  6   2015 median  104 non-null    object
# dtypes: object(7)
# memory usage: 5.9+ KB
# None

# %%
# Convert selected columns to numeric data type
columns_to_convert = ["2020 median", "2019 median", "2018 median", "2017 median", "2016 median", "2015 median"]
newsalarybystate_df[columns_to_convert] = newsalarybystate_df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
# Create a boxplot
newsalarybystate_df.boxplot(column=["2020 median", "2019 median", "2018 median", "2017 median", "2016 median", "2015 median"])

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Median Salary')
plt.title('Median Salary by Year')

# Show the plot
plt.show()

# %%
combined_df = pd.concat([newsalarybystate_df, filtered_df])
# Create a boxplot
combined_df.boxplot(column=['Salary'], by='State')

# Set plot labels and title
plt.xlabel('State')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by State')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[165], line 3
#       1 combined_df = pd.concat([newsalarybystate_df, filtered_df])
#       2 # Create a boxplot
# ----> 3 combined_df.boxplot(column=['Salary'], by='State')
#       5 # Set plot labels and title
#       6 plt.xlabel('State')
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/plotting/_core.py:507, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     490 @Substitution(data="", backend=_backend_doc)
#     491 @Appender(_boxplot_doc)
#     492 def boxplot_frame(
#    (...)
#     504     **kwargs,
#     505 ):
#     506     plot_backend = _get_plot_backend(backend)
# --> 507     return plot_backend.boxplot_frame(
#     508         self,
#     509         column=column,
#     510         by=by,
#     511         ax=ax,
#     512         fontsize=fontsize,
#     513         rot=rot,
#     514         grid=grid,
#     515         figsize=figsize,
#     516         layout=layout,
#     517         return_type=return_type,
#     518         **kwargs,
#     519     )
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/plotting/_matplotlib/boxplot.py:469, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     454 def boxplot_frame(
#     455     self,
#     456     column=None,
#    (...)
#     465     **kwds,
#     466 ):
#     467     import matplotlib.pyplot as plt
# --> 469     ax = boxplot(
#     470         self,
#     471         column=column,
#     472         by=by,
#     473         ax=ax,
#     474         fontsize=fontsize,
#     475         grid=grid,
#     476         rot=rot,
#     477         figsize=figsize,
#     478         layout=layout,
#     479         return_type=return_type,
#     480         **kwds,
#     481     )
#     482     plt.draw_if_interactive()
#     483     return ax
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/plotting/_matplotlib/boxplot.py:415, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     410         columns = [column]
#     412 if by is not None:
#     413     # Prefer array return type for 2-D plots to match the subplot layout
#     414     # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 415     result = _grouped_plot_by_column(
#     416         plot_group,
#     417         data,
#     418         columns=columns,
#     419         by=by,
#     420         grid=grid,
#     421         figsize=figsize,
#     422         ax=ax,
#     423         layout=layout,
#     424         return_type=return_type,
#     425         **kwds,
#     426     )
#     427 else:
#     428     if return_type is None:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/plotting/_matplotlib/boxplot.py:284, in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     282 for i, col in enumerate(columns):
#     283     ax = _axes[i]
# --> 284     gp_col = grouped[col]
#     285     keys, values = zip(*gp_col)
#     286     re_plotf = plotf(keys, values, ax, xlabel=xlabel, ylabel=ylabel, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1771, in DataFrameGroupBy.__getitem__(self, key)
#    1764 if isinstance(key, tuple) and len(key) > 1:
#    1765     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1766     # valid syntax, so don't raise
#    1767     raise ValueError(
#    1768         "Cannot subset columns with a tuple with more than one element. "
#    1769         "Use a list instead."
#    1770     )
# -> 1771 return super().__getitem__(key)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Salary'

# %%
Unemployment_data = Path("../Resources/NEw Filtered UNEMPR.csv")
Unemployment_data = pd.read_csv(Unemployment_data)
Unemployment_data
# Out:
#    STRUCTURE                            STRUCTURE_ID  \
# 0   DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# 1   DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# 2   DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# 3   DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# 4   DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# ..       ...                                     ...
# 58  DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# 59  DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# 60  DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# 61  DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
# 62  DATAFLOW  OECD.ELS.SAE:DSD_LFS@DF_LFS_INDIC(1.1)
#
#                         STRUCTURE_NAME ACTION REF_AREA Reference area  \
# 0   Labour force statistics indicators      I      USA  United States
# 1   Labour force statistics indicators      I      USA  United States
# 2   Labour force statistics indicators      I      USA  United States
# 3   Labour force statistics indicators      I      USA  United States
# 4   Labour force statistics indicators      I      USA  United States
# ..                                 ...    ...      ...            ...
# 58  Labour force statistics indicators      I      USA  United States
# 59  Labour force statistics indicators      I      USA  United States
# 60  Labour force statistics indicators      I      USA  United States
# 61  Labour force statistics indicators      I      USA  United States
# 62  Labour force statistics indicators      I      USA  United States
#
#      MEASURE            Measure UNIT_MEASURE  \
# 0   UNE_RATE  Unemployment rate    PT_LF_SUB
# 1   UNE_RATE  Unemployment rate    PT_LF_SUB
# 2   UNE_RATE  Unemployment rate    PT_LF_SUB
# 3   UNE_RATE  Unemployment rate    PT_LF_SUB
# 4   UNE_RATE  Unemployment rate    PT_LF_SUB
# ..       ...                ...          ...
# 58  UNE_RATE  Unemployment rate    PT_LF_SUB
# 59  UNE_RATE  Unemployment rate    PT_LF_SUB
# 60  UNE_RATE  Unemployment rate    PT_LF_SUB
# 61  UNE_RATE  Unemployment rate    PT_LF_SUB
# 62  UNE_RATE  Unemployment rate    PT_LF_SUB
#
#                                     Unit of measure  ... TIME_PERIOD  \
# 0   Percentage of labour force in the same subgroup  ...        1960
# 1   Percentage of labour force in the same subgroup  ...        1961
# 2   Percentage of labour force in the same subgroup  ...        1962
# 3   Percentage of labour force in the same subgroup  ...        1963
# 4   Percentage of labour force in the same subgroup  ...        1964
# ..                                              ...  ...         ...
# 58  Percentage of labour force in the same subgroup  ...        2018
# 59  Percentage of labour force in the same subgroup  ...        2019
# 60  Percentage of labour force in the same subgroup  ...        2020
# 61  Percentage of labour force in the same subgroup  ...        2021
# 62  Percentage of labour force in the same subgroup  ...        2022
#
#    Time period OBS_VALUE Observation value OBS_STATUS Observation status  \
# 0          NaN  5.384126               NaN          A       Normal value
# 1          NaN  6.506720               NaN          A       Normal value
# 2          NaN  5.361554               NaN          A       Normal value
# 3          NaN  5.456398               NaN          A       Normal value
# 4          NaN  4.995648               NaN          A       Normal value
# ..         ...       ...               ...        ...                ...
# 58         NaN  3.895703               NaN          A       Normal value
# 59         NaN  3.668283               NaN          A       Normal value
# 60         NaN  8.054572               NaN          A       Normal value
# 61         NaN  5.349189               NaN          A       Normal value
# 62         NaN  3.649146               NaN          A       Normal value
#
#     UNIT_MULT  Unit multiplier  DECIMALS  Decimals
# 0         NaN              NaN         1       One
# 1         NaN              NaN         1       One
# 2         NaN              NaN         1       One
# 3         NaN              NaN         1       One
# 4         NaN              NaN         1       One
# ..        ...              ...       ...       ...
# 58        NaN              NaN         1       One
# 59        NaN              NaN         1       One
# 60        NaN              NaN         1       One
# 61        NaN              NaN         1       One
# 62        NaN              NaN         1       One
#
# [63 rows x 26 columns]

# %%
Unemployment_data.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Reference area', 'MEASURE', 'Measure', 'UNIT_MEASURE',
#        'Unit of measure', 'SEX', 'Sex', 'AGE', 'Age', 'LABOUR_FORCE_STATUS',
#        'Labour force status', 'TIME_PERIOD', 'Time period', 'OBS_VALUE',
#        'Observation value', 'OBS_STATUS', 'Observation status', 'UNIT_MULT',
#        'Unit multiplier', 'DECIMALS', 'Decimals'],
#       dtype='object')

# %%
Unemployment_data.dtypes
# Out:
# STRUCTURE               object
# STRUCTURE_ID            object
# STRUCTURE_NAME          object
# ACTION                  object
# REF_AREA                object
# Reference area          object
# MEASURE                 object
# Measure                 object
# UNIT_MEASURE            object
# Unit of measure         object
# SEX                     object
# Sex                     object
# AGE                     object
# Age                     object
# LABOUR_FORCE_STATUS     object
# Labour force status     object
# TIME_PERIOD              int64
# Time period            float64
# OBS_VALUE              float64
# Observation value      float64
# OBS_STATUS              object
# Observation status      object
# UNIT_MULT              float64
# Unit multiplier        float64
# DECIMALS                 int64
# Decimals                object
# dtype: object

# %%
# List of columns to drop
columns_to_drop = ['STRUCTURE', 'STRUCTURE_ID', 
                   'STRUCTURE_NAME', 'ACTION', 
                   'REF_AREA', 'MEASURE', 
                   'UNIT_MEASURE', 'Time period', 
                   'Observation value', 'UNIT_MULT',
                   'Unit multiplier', 'Decimals']

# Drop the columns
Unemployment_data = Unemployment_data.drop(columns=columns_to_drop)

# Save the updated DataFrame to a new CSV file
Unemployment_data.to_csv('updated_UMPR.csv', index=False)

# %%
# List of columns to drop
columns_to_drop = ['SEX', 'AGE', 'LABOUR_FORCE_STATUS', 'OBS_STATUS']

# Drop the columns
Unemployment_data = Unemployment_data.drop(columns=columns_to_drop)

# Save the updated DataFrame to a new CSV file
Unemployment_data.to_csv('updated_UMPR.csv', index=False)

# %%
Unemployment_data
# Out:
#    Reference area            Measure  \
# 0   United States  Unemployment rate
# 1   United States  Unemployment rate
# 2   United States  Unemployment rate
# 3   United States  Unemployment rate
# 4   United States  Unemployment rate
# ..            ...                ...
# 58  United States  Unemployment rate
# 59  United States  Unemployment rate
# 60  United States  Unemployment rate
# 61  United States  Unemployment rate
# 62  United States  Unemployment rate
#
#                                     Unit of measure    Sex    Age  \
# 0   Percentage of labour force in the same subgroup  Total  Total
# 1   Percentage of labour force in the same subgroup  Total  Total
# 2   Percentage of labour force in the same subgroup  Total  Total
# 3   Percentage of labour force in the same subgroup  Total  Total
# 4   Percentage of labour force in the same subgroup  Total  Total
# ..                                              ...    ...    ...
# 58  Percentage of labour force in the same subgroup  Total  Total
# 59  Percentage of labour force in the same subgroup  Total  Total
# 60  Percentage of labour force in the same subgroup  Total  Total
# 61  Percentage of labour force in the same subgroup  Total  Total
# 62  Percentage of labour force in the same subgroup  Total  Total
#
#    Labour force status  TIME_PERIOD  OBS_VALUE Observation status  DECIMALS
# 0         Unemployment         1960   5.384126       Normal value         1
# 1         Unemployment         1961   6.506720       Normal value         1
# 2         Unemployment         1962   5.361554       Normal value         1
# 3         Unemployment         1963   5.456398       Normal value         1
# 4         Unemployment         1964   4.995648       Normal value         1
# ..                 ...          ...        ...                ...       ...
# 58        Unemployment         2018   3.895703       Normal value         1
# 59        Unemployment         2019   3.668283       Normal value         1
# 60        Unemployment         2020   8.054572       Normal value         1
# 61        Unemployment         2021   5.349189       Normal value         1
# 62        Unemployment         2022   3.649146       Normal value         1
#
# [63 rows x 10 columns]

# %%
# 'TIME' and 'Value' are The Year and Unemployment rate values
plt.plot(Unemployment_data['TIME_PERIOD'], Unemployment_data['OBS_VALUE'])

plt.title('Unemployment Rate in US by Year')
plt.xlabel('Year')
plt.ylabel('Rate')

plt.show()

# %%
# Dictionary of old column names and new column names
column_names = {'TIME_PERIOD': 'TIME'}

# Rename the columns
Unemployment_data = Unemployment_data.rename(columns=column_names)

# Save the updated DataFrame to a new CSV file
Unemployment_data.to_csv('updated_UMPR.csv', index=False)

# %%
Suicide_Rates = Path("../Resources/Suicide Rates.csv")
Suicide_Rates = pd.read_csv(Suicide_Rates)
Suicide_Rates.head()
# Out:
#   LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value Flag Codes
# 0      AUS   SUICIDE     TOT  100000PER         A  1960   13.6        NaN
# 1      AUS   SUICIDE     TOT  100000PER         A  1961   15.0        NaN
# 2      AUS   SUICIDE     TOT  100000PER         A  1962   17.4        NaN
# 3      AUS   SUICIDE     TOT  100000PER         A  1963   19.8        NaN
# 4      AUS   SUICIDE     TOT  100000PER         A  1964   18.4        NaN

# %%
# Filter the DataFrame
Suicide_Rates = Suicide_Rates[Suicide_Rates['LOCATION'] == 'USA']

Suicide_Rates = Suicide_Rates[Suicide_Rates['SUBJECT'] == 'TOT']

# Save the filtered DataFrame to a new CSV file
Suicide_Rates.to_csv('filtered_Suicide_Rates.csv', index=False)

# %%
Suicide_Rates
# Out:
#      LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value Flag Codes
# 1537      USA   SUICIDE     TOT  100000PER         A  1960   13.9        NaN
# 1538      USA   SUICIDE     TOT  100000PER         A  1961   13.6        NaN
# 1539      USA   SUICIDE     TOT  100000PER         A  1962   14.2        NaN
# 1540      USA   SUICIDE     TOT  100000PER         A  1963   14.3        NaN
# 1541      USA   SUICIDE     TOT  100000PER         A  1964   14.0        NaN
# ...       ...       ...     ...        ...       ...   ...    ...        ...
# 1593      USA   SUICIDE     TOT  100000PER         A  2016   14.2        NaN
# 1594      USA   SUICIDE     TOT  100000PER         A  2017   14.8        NaN
# 1595      USA   SUICIDE     TOT  100000PER         A  2018   15.0        NaN
# 1596      USA   SUICIDE     TOT  100000PER         A  2019   14.7        NaN
# 1597      USA   SUICIDE     TOT  100000PER         A  2020   14.1        NaN
#
# [61 rows x 8 columns]

# %%
Suicide_Rates.dtypes
# Out:
# LOCATION       object
# INDICATOR      object
# SUBJECT        object
# MEASURE        object
# FREQUENCY      object
# TIME            int64
# Value         float64
# Flag Codes     object
# dtype: object

# %%
Suicide_Rates.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
plt.plot(Suicide_Rates['TIME'], Suicide_Rates['Value'])

plt.title('Suicide Rate in US by Year')
plt.xlabel('Year')
plt.ylabel('Rate')

plt.show()

# %%
# Merge the DataFrames on the year column
merged_df = pd.merge(Unemployment_data, Suicide_Rates, on='TIME')

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('merged_UNEMPR_SR.csv', index=False)

# %%
UnEmp_SR = Path("merged_UNEMPR_SR.csv")
UnEmp_SR = pd.read_csv(UnEmp_SR)
UnEmp_SR.head()
# Out:
#   Reference area            Measure  \
# 0  United States  Unemployment rate
# 1  United States  Unemployment rate
# 2  United States  Unemployment rate
# 3  United States  Unemployment rate
# 4  United States  Unemployment rate
#
#                                    Unit of measure    Sex    Age  \
# 0  Percentage of labour force in the same subgroup  Total  Total
# 1  Percentage of labour force in the same subgroup  Total  Total
# 2  Percentage of labour force in the same subgroup  Total  Total
# 3  Percentage of labour force in the same subgroup  Total  Total
# 4  Percentage of labour force in the same subgroup  Total  Total
#
#   Labour force status  TIME  OBS_VALUE Observation status  DECIMALS LOCATION  \
# 0        Unemployment  1960   5.384126       Normal value         1      USA
# 1        Unemployment  1961   6.506720       Normal value         1      USA
# 2        Unemployment  1962   5.361554       Normal value         1      USA
# 3        Unemployment  1963   5.456398       Normal value         1      USA
# 4        Unemployment  1964   4.995648       Normal value         1      USA
#
#   INDICATOR SUBJECT    MEASURE FREQUENCY  Value Flag Codes
# 0   SUICIDE     TOT  100000PER         A   13.9        NaN
# 1   SUICIDE     TOT  100000PER         A   13.6        NaN
# 2   SUICIDE     TOT  100000PER         A   14.2        NaN
# 3   SUICIDE     TOT  100000PER         A   14.3        NaN
# 4   SUICIDE     TOT  100000PER         A   14.0        NaN

# %%
# List of columns to drop
columns_to_drop = ['Flag Codes', 'DECIMALS', 'Sex', 'Age', 'Observation status', 'SUBJECT', 'FREQUENCY']

# Drop the columns
UnEmp_SR = UnEmp_SR.drop(columns=columns_to_drop)

# Save the updated DataFrame to a new CSV file
UnEmp_SR.to_csv('merged_UNEMPR_SR.csv', index=False)

# %%
UnEmp_SR
# Out:
#    Reference area            Measure  \
# 0   United States  Unemployment rate
# 1   United States  Unemployment rate
# 2   United States  Unemployment rate
# 3   United States  Unemployment rate
# 4   United States  Unemployment rate
# ..            ...                ...
# 56  United States  Unemployment rate
# 57  United States  Unemployment rate
# 58  United States  Unemployment rate
# 59  United States  Unemployment rate
# 60  United States  Unemployment rate
#
#                                     Unit of measure Labour force status  TIME  \
# 0   Percentage of labour force in the same subgroup        Unemployment  1960
# 1   Percentage of labour force in the same subgroup        Unemployment  1961
# 2   Percentage of labour force in the same subgroup        Unemployment  1962
# 3   Percentage of labour force in the same subgroup        Unemployment  1963
# 4   Percentage of labour force in the same subgroup        Unemployment  1964
# ..                                              ...                 ...   ...
# 56  Percentage of labour force in the same subgroup        Unemployment  2016
# 57  Percentage of labour force in the same subgroup        Unemployment  2017
# 58  Percentage of labour force in the same subgroup        Unemployment  2018
# 59  Percentage of labour force in the same subgroup        Unemployment  2019
# 60  Percentage of labour force in the same subgroup        Unemployment  2020
#
#     OBS_VALUE LOCATION INDICATOR    MEASURE  Value
# 0    5.384126      USA   SUICIDE  100000PER   13.9
# 1    6.506720      USA   SUICIDE  100000PER   13.6
# 2    5.361554      USA   SUICIDE  100000PER   14.2
# 3    5.456398      USA   SUICIDE  100000PER   14.3
# 4    4.995648      USA   SUICIDE  100000PER   14.0
# ..        ...      ...       ...        ...    ...
# 56   4.870250      USA   SUICIDE  100000PER   14.2
# 57   4.356233      USA   SUICIDE  100000PER   14.8
# 58   3.895703      USA   SUICIDE  100000PER   15.0
# 59   3.668283      USA   SUICIDE  100000PER   14.7
# 60   8.054572      USA   SUICIDE  100000PER   14.1
#
# [61 rows x 10 columns]

# %%
# Dictionary of old column names and new column names
column_names = {'OBS_VALUE': 'Unemployment Rate', 'Value': 'Suicide Rate'}

# Rename the columns
UnEmp_SR = UnEmp_SR.rename(columns=column_names)

# Save the updated DataFrame to a new CSV file
UnEmp_SR.to_csv('merged_UNEMPR_SR.csv', index=False)

# %%
UnEmp_SR.head()
# Out:
#   Reference area            Measure  \
# 0  United States  Unemployment rate
# 1  United States  Unemployment rate
# 2  United States  Unemployment rate
# 3  United States  Unemployment rate
# 4  United States  Unemployment rate
#
#                                    Unit of measure Labour force status  TIME  \
# 0  Percentage of labour force in the same subgroup        Unemployment  1960
# 1  Percentage of labour force in the same subgroup        Unemployment  1961
# 2  Percentage of labour force in the same subgroup        Unemployment  1962
# 3  Percentage of labour force in the same subgroup        Unemployment  1963
# 4  Percentage of labour force in the same subgroup        Unemployment  1964
#
#    Unemployment Rate LOCATION INDICATOR    MEASURE  Suicide Rate
# 0           5.384126      USA   SUICIDE  100000PER          13.9
# 1           6.506720      USA   SUICIDE  100000PER          13.6
# 2           5.361554      USA   SUICIDE  100000PER          14.2
# 3           5.456398      USA   SUICIDE  100000PER          14.3
# 4           4.995648      USA   SUICIDE  100000PER          14.0

# %%
plt.scatter(UnEmp_SR['Unemployment Rate'], UnEmp_SR['Suicide Rate'])

plt.title('Scatter Plot of Unemployment Rate vs Suicide Rate')
plt.xlabel('Unemployment Rate')
plt.ylabel('Suicide Rate')

# Assuming 'column1' and 'column2' are columns in your DataFrame
correlation = UnEmp_SR['Unemployment Rate'].corr(UnEmp_SR['Suicide Rate'])

print("Pearson correlation coefficient:", correlation)

plt.show()
# Out:
# Pearson correlation coefficient: 0.009638250375919932

# %%
# Dictionary of old column names and new column names
column_names = {'TIME': 'Year'}

# Rename the columns
UnEmp_SR = UnEmp_SR.rename(columns=column_names)

# Save the updated DataFrame to a new CSV file
UnEmp_SR.to_csv('merged_UNEMPR_SR.csv', index=False)

# %%
UnEmp_SR = UnEmp_SR[(UnEmp_SR['Year'] >= 2015) & (UnEmp_SR['Year'] <= 2020)]

# %%
plt.plot(UnEmp_SR['Year'], UnEmp_SR['Suicide Rate'], label='Suicide Rate') 
plt.plot(UnEmp_SR['Year'], UnEmp_SR['Unemployment Rate'], label='Unemployment Rate') 

plt.xlabel('Years')
plt.ylabel('Rates')
plt.title('Suicide Rates and Unemployment Rates')

plt.legend()
plt.show()

# %%
x_values = UnEmp_SR['Suicide Rate']
y_values = UnEmp_SR['Unemployment Rate']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Suicide Rate')
plt.ylabel('Unemployment Rate')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.48481041009454284

# %%
data = UnEmp_SR['Suicide Rate']  

# Step 4: Use the normaltest function to check for normality
k2, p = normaltest(data)

# Step 5: Print the result
print("p = {:g}".format(p))

alpha = 0.05
if p < alpha:  # null hypothesis: data comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis cannot be rejected")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qp/3664dv2s37jbnnkfd9kgkt500000gp/T/ipykernel_78024/3583904387.py in ?()
#       1 data = UnEmp_SR['Suicide Rate']
#       2
#       3 # Step 4: Use the normaltest function to check for normality
# ----> 4 k2, p = normaltest(data)
#       5
#       6 # Step 5: Print the result
#       7 print("p = {:g}".format(p))
#
# ~/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(a, axis, nan_policy)
#    1988     if contains_nan and nan_policy == 'omit':
#    1989         a = ma.masked_invalid(a)
#    1990         return mstats_basic.normaltest(a, axis)
#    1991
# -> 1992     s, _ = skewtest(a, axis)
#    1993     k, _ = kurtosistest(a, axis)
#    1994     k2 = s*s + k*k
#    1995
#
# ~/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(a, axis, nan_policy, alternative)
#    1605         axis = 0
#    1606     b2 = skew(a, axis)
#    1607     n = a.shape[axis]
#    1608     if n < 8:
# -> 1609         raise ValueError(
#    1610             "skewtest is not valid with less than 8 samples; %i samples"
#    1611             " were given." % int(n))
#    1612     y = b2 * math.sqrt(((n + 1) * (n + 3)) / (6.0 * (n - 2)))
#
# ValueError: skewtest is not valid with less than 8 samples; 6 samples were given.

# %%
Q1 = UnEmp_SR['Suicide Rate'].quantile(0.25)
Q3 = UnEmp_SR['Suicide Rate'].quantile(0.75)
IQR = Q3 - Q1

filter = (UnEmp_SR['Suicide Rate'] >= Q1 - 1.5 * IQR) & (UnEmp_SR['Suicide Rate'] <= Q3 + 1.5 *IQR)
UnEmp_SR_no_outlier = UnEmp_SR.loc[filter]

# %%
# Boxplot before removing outliers
plt.figure(figsize=(12, 6))
plt.subplot(121)
UnEmp_SR['Suicide Rate'].plot(kind='box')
plt.title('Boxplot Before Removing Outliers')

# Boxplot after removing outliers
plt.subplot(122)
UnEmp_SR_no_outlier['Suicide Rate'].plot(kind='box')
plt.title('Boxplot After Removing Outliers')

plt.show()

# Histogram before removing outliers
plt.figure(figsize=(12, 6))
plt.subplot(121)
UnEmp_SR['Suicide Rate'].plot(kind='hist', bins=30)
plt.title('Histogram Before Removing Outliers')

# Histogram after removing outliers
plt.subplot(122)
UnEmp_SR_no_outlier['Suicide Rate'].plot(kind='hist', bins=30)
plt.title('Histogram After Removing Outliers')

plt.show()

# %%
data = UnEmp_SR['Unemployment Rate']  

# Step 4: Use the normaltest function to check for normality
k2, p = normaltest(data)

# Step 5: Print the result
print("p = {:g}".format(p))

alpha = 0.05
if p < alpha:  # null hypothesis: data comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis cannot be rejected")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qp/3664dv2s37jbnnkfd9kgkt500000gp/T/ipykernel_78024/1656929839.py in ?()
#       1 data = UnEmp_SR['Unemployment Rate']
#       2
#       3 # Step 4: Use the normaltest function to check for normality
# ----> 4 k2, p = normaltest(data)
#       5
#       6 # Step 5: Print the result
#       7 print("p = {:g}".format(p))
#
# ~/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(a, axis, nan_policy)
#    1988     if contains_nan and nan_policy == 'omit':
#    1989         a = ma.masked_invalid(a)
#    1990         return mstats_basic.normaltest(a, axis)
#    1991
# -> 1992     s, _ = skewtest(a, axis)
#    1993     k, _ = kurtosistest(a, axis)
#    1994     k2 = s*s + k*k
#    1995
#
# ~/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(a, axis, nan_policy, alternative)
#    1605         axis = 0
#    1606     b2 = skew(a, axis)
#    1607     n = a.shape[axis]
#    1608     if n < 8:
# -> 1609         raise ValueError(
#    1610             "skewtest is not valid with less than 8 samples; %i samples"
#    1611             " were given." % int(n))
#    1612     y = b2 * math.sqrt(((n + 1) * (n + 3)) / (6.0 * (n - 2)))
#
# ValueError: skewtest is not valid with less than 8 samples; 6 samples were given.

# %%
# Create a contingency table
contingency_table = pd.crosstab(UnEmp_SR['Unemployment Rate'], UnEmp_SR['Suicide Rate'])

# Perform the Chi-Squared test
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

# Print the results
print(f"Chi2 value: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
# Out:
# Chi2 value: 30.000000000000007
# P-value: 0.22428900483440348
# Degrees of freedom: 25
